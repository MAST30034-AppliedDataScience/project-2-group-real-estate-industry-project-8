# %% [markdown]
# # ABS preprocessing
#
# This notebook aggregates the Openspace data such that the relevant fields are extracted and the data is neatly formatted into a csv wherein the rows are associated with an SA2

# %%
import pandas as pd
import geopandas as gpd

# %%
shape_file = gpd.read_file('../../data/landing/Open_Space/VPA_Draft_Open_Space_Data.shp')
sal_shape_file = gpd.read_file('../../data/landing/SAL_data/SAL_2021_AUST_GDA2020.shp')

shape_file
# Out:
#          FID         LGA     VM_PARCEL_ VM_PARCE_1               DATA_SOURC  \
# 0          1  BOROONDARA      3\LP28215      95086  VM Features of Interest
# 1          2  BOROONDARA     159\LP5481  203973157               VM Parcels
# 2          3  BOROONDARA      3\TP84208  203973089               VM Parcels
# 3          4  BOROONDARA      1\TP84208  203973073               VM Parcels
# 4          5  BOROONDARA     1\TP802753  203972979               VM Parcels
# ...      ...         ...            ...        ...                      ...
# 38805  38806   FRANKSTON           None       None        Frankston Council
# 38806  38807       YARRA      2\LP38905    2015149               VM Parcels
# 38807  38808   FRANKSTON        NO DATA    NO DATA          Melbourne Water
# 38808  38809   FRANKSTON       CP151911    1114997               VM Parcels
# 38809  38810   FRANKSTON  RES1\PS616669  211759478               VM Parcels
#
#                                 OS_CATEGOR      OS_CATEG_2        OWNER_TYPE  \
# 0                    Tertiary institutions  Not applicable  State Government
# 1                        Parks and gardens  Not applicable  Local government
# 2                        Parks and gardens  Not applicable  Local government
# 3                        Parks and gardens  Not applicable  Local government
# 4                        Parks and gardens  Not applicable  Local government
# ...                                    ...             ...               ...
# 38805               Transport reservations     Median park  Local government
# 38806               Non-government schools  Not applicable           Private
# 38807  Natural and semi-natural open space  Not applicable  Public authority
# 38808                    Parks and gardens  Not applicable  Local government
# 38809               Transport reservations    Green buffer  Local government
#
#                                                PARK_NAME OS_STATUS  ...  \
# 0      Swinburne University Of Technology & Tafe Divi...  Existing  ...
# 1                                  Kate Campbell Reserve  Existing  ...
# 2                                  Kate Campbell Reserve  Existing  ...
# 3                                  Kate Campbell Reserve  Existing  ...
# 4                                  Kate Campbell Reserve  Existing  ...
# ...                                                  ...       ...  ...
# 38805                            Taverner Square Reserve  Existing  ...
# 38806                      St Kevins College - Waterford  Existing  ...
# 38807                          Seaford Swamp (MWC Drain)  Existing  ...
# 38808                                  Broughton Reserve  Existing  ...
# 38809                       McCormicks Road Reserve Link  Existing  ...
#
#       WATER_BODY                 OS_TYPE  COASTAL         MANAGER_NA  \
# 0           None  Restricted public land     None            NO DATA
# 1           None       Public open space     None            NO DATA
# 2           None       Public open space     None            NO DATA
# 3           None       Public open space     None            NO DATA
# 4           None       Public open space     None            NO DATA
# ...          ...                     ...      ...                ...
# 38805       None       Public open space     None            NO DATA
# 38806       None      Private open space     None            NO DATA
# 38807       None       Public open space     None            NO DATA
# 38808       None       Public open space     None  Frankston Council
# 38809       None  Restricted public land     None  Frankston Council
#
#                                OWNER_NAME  \
# 0      Swinburne University of Technology
# 1                 Boroondara City Council
# 2                 Boroondara City Council
# 3                 Boroondara City Council
# 4                 Boroondara City Council
# ...                                   ...
# 38805              Frankston City Council
# 38806                             NO DATA
# 38807         Melbourne Water Corporation
# 38808              Frankston City Council
# 38809              Frankston City Council
#
#                                                Image_URL VPA_ID SHAPE_Leng  \
# 0      https://lh3.googleusercontent.com/-QP2NylEZuhE...   1500   0.000742
# 1      https://lh3.googleusercontent.com/-rdTUgqfNyXg...   1501   0.001105
# 2      https://lh3.googleusercontent.com/-rdTUgqfNyXg...   1502   0.001003
# 3      https://lh3.googleusercontent.com/-rdTUgqfNyXg...   1503   0.001102
# 4      https://lh3.googleusercontent.com/-rdTUgqfNyXg...   1504   0.001327
# ...                                                  ...    ...        ...
# 38805  https://lh3.googleusercontent.com/-7jagzn1L1NA...  39508   0.002004
# 38806  https://lh3.googleusercontent.com/-uz6koGrYKZE...  39509   0.000825
# 38807  https://lh3.googleusercontent.com/-mCSb2HRxCUs...  39303   0.008203
# 38808  https://lh3.googleusercontent.com/-rdTUgqfNyXg...  39304   0.003781
# 38809  https://lh3.googleusercontent.com/-7jagzn1L1NA...  39305   0.003604
#
#          SHAPE_Area                                           geometry
# 0      1.698581e-08  POLYGON ((145.03932 -37.82299, 145.03937 -37.8...
# 1      6.526377e-08  POLYGON ((145.03436 -37.79175, 145.03443 -37.7...
# 2      5.615414e-08  POLYGON ((145.0348 -37.79127, 145.03487 -37.79...
# 3      6.530917e-08  POLYGON ((145.03515 -37.79131, 145.03522 -37.7...
# 4      9.438898e-08  POLYGON ((145.03549 -37.79136, 145.03557 -37.7...
# ...             ...                                                ...
# 38805  2.802900e-07  POLYGON ((145.15155 -38.17352, 145.15155 -38.1...
# 38806  2.976525e-08  POLYGON ((144.99825 -37.82099, 144.9983 -37.82...
# 38807  4.191129e-06  POLYGON ((145.13578 -38.09732, 145.1361 -38.09...
# 38808  4.406187e-07  POLYGON ((145.12702 -38.10245, 145.12721 -38.1...
# 38809  1.020670e-08  POLYGON ((145.20033 -38.08566, 145.20039 -38.0...
#
# [38810 rows x 25 columns]

# %%
filtered_gdf_private = shape_file[['OS_CATEGOR', 'OWNER_NAME','PARK_NAME', 'geometry']]

filtered_gdf_private


types_in_SA2 = gpd.sjoin(sal_shape_file, filtered_gdf_private , how="inner", predicate="intersects")
# Out:
# /var/folders/vs/mmhmvz2124bdlbwz4b6zdqqh0000gn/T/ipykernel_64430/3548199687.py:6: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:7844
# Right CRS: EPSG:4326
#
#   types_in_SA2 = gpd.sjoin(sal_shape_file, filtered_gdf_private , how="inner", predicate="intersects")

# %%
# Aggregate all the columns with the same PARK_NAME by keeping only one element
aggregated_by_park_name = filtered_gdf_private.groupby('PARK_NAME').first().reset_index()

aggregated_by_park_name
# Out:
#                                                PARK_NAME  \
# 0                          1 Clydebank Rd, Essendon West
# 1      1 Nepean Highway walkway between Hotel and Mor...
# 2                                1 Padey Drive, Mulgrave
# 3                              1-13 Somerfield Drive Res
# 4                  1-3 St Clair Crescent, Mount Waverley
# ...                                                  ...
# 11824           strip of land with vegetation - Cardinia
# 11825                                                  v
# 11826                    various Retarding Basins - Hume
# 11827                          vested in Water Authority
# 11828                                                  y
#
#                                 OS_CATEGOR                      OWNER_NAME  \
# 0                   Transport reservations                        VicRoads
# 1                      Recreation corridor           Kingston City Council
# 2                        Parks and gardens             Monash City Council
# 3                        Parks and gardens  Greater Dandenong City Council
# 4                        Parks and gardens             Monash City Council
# ...                                    ...                             ...
# 11824  Natural and semi-natural open space                           Crown
# 11825               Transport reservations                        VicRoads
# 11826  Natural and semi-natural open space     Melbourne Water Corporation
# 11827      Services and utilities reserves                           Crown
# 11828  Natural and semi-natural open space            Banyule City Council
#
#                                                 geometry
# 0      POLYGON ((144.88756 -37.75395, 144.8878 -37.75...
# 1      POLYGON ((145.08772 -38.01003, 145.08778 -38.0...
# 2      POLYGON ((145.19468 -37.92615, 145.19456 -37.9...
# 3      POLYGON ((145.17531 -38.0065, 145.17631 -38.00...
# 4      POLYGON ((145.14731 -37.87291, 145.14712 -37.8...
# ...                                                  ...
# 11824  POLYGON ((145.62107 -38.05668, 145.62118 -38.0...
# 11825  POLYGON ((145.09082 -37.70306, 145.09076 -37.7...
# 11826  POLYGON ((144.89067 -37.67675, 144.89064 -37.6...
# 11827  POLYGON ((145.31995 -38.19631, 145.32 -38.1960...
# 11828  POLYGON ((145.11055 -37.7058, 145.11054 -37.70...
#
# [11829 rows x 4 columns]

# %%
# Pivot the data to aggregate by 'SA2_CODE21' and count occurrences of each 'OS_CATEGOR'
aggregated_df = types_in_SA2.pivot_table(index='SAL_CODE21', columns='OS_CATEGOR', aggfunc='size', fill_value=0)

aggregated_df
# Out:
# OS_CATEGOR  Cemeteries  Civic squares and promenades  Conservation reserves  \
# SAL_CODE21
# 20002                0                             0                      0
# 20003                0                             0                      0
# 20006                0                             0                      0
# 20011                0                             0                      0
# 20015                0                             0                      0
# ...                ...                           ...                    ...
# 22911                1                             0                      2
# 22916                0                             0                      0
# 22917                1                             0                      0
# 22925                0                             0                     64
# 22930                0                             0                      5
#
# OS_CATEGOR  Government schools  Natural and semi-natural open space  \
# SAL_CODE21
# 20002                        1                                   15
# 20003                        1                                    2
# 20006                        0                                    2
# 20011                        0                                    6
# 20015                        1                                    3
# ...                        ...                                  ...
# 22911                        3                                   24
# 22916                        1                                   23
# 22917                        6                                   21
# 22925                        1                                   22
# 22930                        1                                    7
#
# OS_CATEGOR  Non-government schools  Parks and gardens  \
# SAL_CODE21
# 20002                            2                 31
# 20003                            5                  3
# 20006                            0                  0
# 20011                            0                  0
# 20015                            1                 16
# ...                            ...                ...
# 22911                            3                  3
# 22916                            1                  0
# 22917                            1                 33
# 22925                            0                  0
# 22930                            0                  0
#
# OS_CATEGOR  Public housing reserves  Recreation corridor  \
# SAL_CODE21
# 20002                             0                    1
# 20003                             0                    2
# 20006                             0                    0
# 20011                             0                    0
# 20015                             0                    8
# ...                             ...                  ...
# 22911                             0                    6
# 22916                             0                    0
# 22917                             0                    0
# 22925                             0                    0
# 22930                             0                   15
#
# OS_CATEGOR  Services and utilities reserves  \
# SAL_CODE21
# 20002                                     0
# 20003                                     0
# 20006                                     0
# 20011                                     0
# 20015                                     0
# ...                                     ...
# 22911                                    31
# 22916                                     0
# 22917                                     0
# 22925                                    15
# 22930                                     0
#
# OS_CATEGOR  Sportsfields and organised recreation  Tertiary institutions  \
# SAL_CODE21
# 20002                                           1                      0
# 20003                                           2                      0
# 20006                                           0                      0
# 20011                                           0                      0
# 20015                                           2                      0
# ...                                           ...                    ...
# 22911                                           6                      0
# 22916                                           7                      0
# 22917                                          15                      0
# 22925                                           3                      0
# 22930                                           4                      0
#
# OS_CATEGOR  Transport reservations
# SAL_CODE21
# 20002                            0
# 20003                            1
# 20006                            0
# 20011                            0
# 20015                            4
# ...                            ...
# 22911                            0
# 22916                            3
# 22917                            2
# 22925                            0
# 22930                            0
#
# [569 rows x 13 columns]

# %%
# Reset the index to turn the aggregated table into a normal DataFrame
normal_df = aggregated_df.reset_index()

normal_df
# Out:
# OS_CATEGOR SAL_CODE21  Cemeteries  Civic squares and promenades  \
# 0               20002           0                             0
# 1               20003           0                             0
# 2               20006           0                             0
# 3               20011           0                             0
# 4               20015           0                             0
# ..                ...         ...                           ...
# 564             22911           1                             0
# 565             22916           0                             0
# 566             22917           1                             0
# 567             22925           0                             0
# 568             22930           0                             0
#
# OS_CATEGOR  Conservation reserves  Government schools  \
# 0                               0                   1
# 1                               0                   1
# 2                               0                   0
# 3                               0                   0
# 4                               0                   1
# ..                            ...                 ...
# 564                             2                   3
# 565                             0                   1
# 566                             0                   6
# 567                            64                   1
# 568                             5                   1
#
# OS_CATEGOR  Natural and semi-natural open space  Non-government schools  \
# 0                                            15                       2
# 1                                             2                       5
# 2                                             2                       0
# 3                                             6                       0
# 4                                             3                       1
# ..                                          ...                     ...
# 564                                          24                       3
# 565                                          23                       1
# 566                                          21                       1
# 567                                          22                       0
# 568                                           7                       0
#
# OS_CATEGOR  Parks and gardens  Public housing reserves  Recreation corridor  \
# 0                          31                        0                    1
# 1                           3                        0                    2
# 2                           0                        0                    0
# 3                           0                        0                    0
# 4                          16                        0                    8
# ..                        ...                      ...                  ...
# 564                         3                        0                    6
# 565                         0                        0                    0
# 566                        33                        0                    0
# 567                         0                        0                    0
# 568                         0                        0                   15
#
# OS_CATEGOR  Services and utilities reserves  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
# ..                                      ...
# 564                                      31
# 565                                       0
# 566                                       0
# 567                                      15
# 568                                       0
#
# OS_CATEGOR  Sportsfields and organised recreation  Tertiary institutions  \
# 0                                               1                      0
# 1                                               2                      0
# 2                                               0                      0
# 3                                               0                      0
# 4                                               2                      0
# ..                                            ...                    ...
# 564                                             6                      0
# 565                                             7                      0
# 566                                            15                      0
# 567                                             3                      0
# 568                                             4                      0
#
# OS_CATEGOR  Transport reservations
# 0                                0
# 1                                1
# 2                                0
# 3                                0
# 4                                4
# ..                             ...
# 564                              0
# 565                              3
# 566                              2
# 567                              0
# 568                              0
#
# [569 rows x 14 columns]

# %%
normal_df.rename(columns={'SAL_CODE21': 'SAL_CODE'}, inplace=True)

normal_df.to_csv('../../data/curated/open_space.csv', index=False)
