# %% [markdown]
# # Crime ARIMA
# Only crime data for 2016-2024 in this notebook, we perform an ARIMA on the data to forecast data for 2024 to 2028.

# %%
# import necessary libraries
import pandas as pd
import statsmodels.api as sm
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
# read in the crime data
crime_df = pd.read_csv("../../data/curated/crime_suburb_data.csv")
crime_df
# Out:
#      suburb_name  SAL_CODE_2021  2015_A Crimes against the person  \
# 0       Abbeyard          20001                                 0
# 1     Abbotsford          20002                                10
# 2     Aberfeldie          20003                                 6
# 3      Aberfeldy          20004                                 0
# 4        Acheron          20005                                 1
# ...          ...            ...                               ...
# 2842     Yundool          22940                                 1
# 2843      Yuroke          22941                                 1
# 2844     Yuulong          22942                                 0
# 2845     Zeerust          22943                                 1
# 2846   Zumsteins          22944                                 0
#
#       2015_B Property and deception offences  2015_C Drug offences  \
# 0                                          0                     0
# 1                                         18                     3
# 2                                         11                     2
# 3                                          0                     0
# 4                                          1                     0
# ...                                      ...                   ...
# 2842                                       0                     0
# 2843                                       7                     0
# 2844                                       2                     1
# 2845                                       2                     0
# 2846                                       0                     0
#
#       2015_D Public order and security offences  \
# 0                                             1
# 1                                             7
# 2                                             0
# 3                                             0
# 4                                             0
# ...                                         ...
# 2842                                          0
# 2843                                          0
# 2844                                          0
# 2845                                          0
# 2846                                          0
#
#       2015_E Justice procedures offences  2015_F Other offences  2015_total  \
# 0                                      0                      1           2
# 1                                      4                      0          42
# 2                                      1                      0          20
# 3                                      0                      1           1
# 4                                      0                      0           2
# ...                                  ...                    ...         ...
# 2842                                   0                      0           1
# 2843                                   2                      0          10
# 2844                                   0                      0           3
# 2845                                   0                      0           3
# 2846                                   0                      0           0
#
#       2016_A Crimes against the person  ...  2023_F Other offences  \
# 0                                    0  ...                      0
# 1                                   13  ...                      1
# 2                                    8  ...                      0
# 3                                    0  ...                      0
# 4                                    0  ...                      0
# ...                                ...  ...                    ...
# 2842                                 0  ...                      0
# 2843                                 1  ...                      0
# 2844                                 0  ...                      0
# 2845                                 5  ...                      0
# 2846                                 0  ...                      0
#
#       2023_total  2024_A Crimes against the person  \
# 0              0                                 0
# 1             49                                11
# 2             22                                 7
# 3              0                                 0
# 4              1                                 1
# ...          ...                               ...
# 2842           0                                 0
# 2843           7                                 2
# 2844           2                                 0
# 2845           6                                 0
# 2846           0                                 0
#
#       2024_B Property and deception offences  2024_C Drug offences  \
# 0                                          0                     0
# 1                                         16                     4
# 2                                         11                     0
# 3                                          0                     0
# 4                                          0                     0
# ...                                      ...                   ...
# 2842                                       0                     0
# 2843                                       4                     0
# 2844                                       0                     0
# 2845                                       1                     0
# 2846                                       0                     0
#
#       2024_D Public order and security offences  \
# 0                                             0
# 1                                             8
# 2                                             2
# 3                                             0
# 4                                             0
# ...                                         ...
# 2842                                          0
# 2843                                          1
# 2844                                          0
# 2845                                          0
# 2846                                          0
#
#       2024_E Justice procedures offences  2024_F Other offences  2024_total  \
# 0                                      0                      0           0
# 1                                      6                      1          46
# 2                                      3                      0          23
# 3                                      0                      0           0
# 4                                      1                      0           2
# ...                                  ...                    ...         ...
# 2842                                   0                      0           0
# 2843                                   1                      0           8
# 2844                                   0                      0           0
# 2845                                   1                      0           2
# 2846                                   0                      0           0
#
#       all_crimes_2015-2024
# 0                        7
# 1                      479
# 2                      238
# 3                        2
# 4                       27
# ...                    ...
# 2842                     5
# 2843                    78
# 2844                     9
# 2845                    46
# 2846                     6
#
# [2847 rows x 73 columns]

# %%
# read in historical rent data to get a list of SAL codes that we need to ARIMA the business data on
historical_rent_df = pd.read_csv("../../data/curated/historical_rent_cleaned.csv")
print(historical_rent_df.shape)
historical_rent_df.head(5)
# Out:
# (567, 51)
#    SAL_CODE  2000_average_weekly_rent  2000_average_quarterly_count  \
# 0     20111                     137.0                        979.50
# 1     20198                     190.0                        505.75
# 2     21193                     200.0                        608.25
# 3     21640                     320.0                       2278.75
# 4     21938                     142.5                        443.50
#
#    2001_average_weekly_rent  2001_average_quarterly_count  \
# 0                    141.25                        857.00
# 1                    207.75                        502.50
# 2                    207.50                        765.50
# 3                    320.00                       2752.50
# 4                    151.25                        434.75
#
#    2002_average_weekly_rent  2002_average_quarterly_count  \
# 0                    151.25                        896.00
# 1                    216.25                        529.00
# 2                    210.00                       1059.50
# 3                    320.00                       3382.75
# 4                    161.25                        429.50
#
#    2003_average_weekly_rent  2003_average_quarterly_count  \
# 0                    161.25                        948.25
# 1                    221.25                        525.75
# 2                    210.00                       1334.00
# 3                    305.00                       3972.75
# 4                    171.25                        473.00
#
#    2004_average_weekly_rent  ...  2020_average_weekly_rent  \
# 0                    171.25  ...                    317.50
# 1                    226.25  ...                    466.25
# 2                    217.50  ...                    400.00
# 3                    300.00  ...                    483.75
# 4                    178.75  ...                    390.75
#
#    2020_average_quarterly_count  2021_average_weekly_rent  \
# 0                       1743.75                    331.25
# 1                        720.00                    457.00
# 2                       2389.25                    400.00
# 3                      10206.25                    366.25
# 4                        434.50                    407.50
#
#    2021_average_quarterly_count  2022_average_weekly_rent  \
# 0                       1632.25                    355.00
# 1                        643.25                    432.50
# 2                       2591.50                    411.25
# 3                      16559.25                    426.25
# 4                        428.50                    432.50
#
#    2022_average_quarterly_count  2023_average_weekly_rent  \
# 0                       1546.50                    371.25
# 1                        872.25                    495.00
# 2                       3047.50                    437.50
# 3                      14627.75                    587.50
# 4                        365.25                    465.00
#
#    2023_average_quarterly_count  2024_average_weekly_rent  \
# 0                       1473.25                     380.0
# 1                        764.75                     550.0
# 2                       3557.00                     470.0
# 3                      13547.25                     640.0
# 4                        312.50                     475.0
#
#    2024_average_quarterly_count
# 0                        1345.0
# 1                         729.0
# 2                        3777.0
# 3                       13582.0
# 4                         356.0
#
# [5 rows x 51 columns]

# %%
# variable assignment cell in preparation for the ARIMA
df = crime_df
sal_codes = list(historical_rent_df["SAL_CODE"].unique())
crime_types = ["A Crimes against the person", "B Property and deception offences", "C Drug offences", 
                   "D Public order and security offences", "E Justice procedures offences",	"F Other offences"]
print(len(sal_codes))
# Out:
# 567

# %%
df.dtypes
# Out:
# suburb_name                                  object
# SAL_CODE_2021                                 int64
# 2015_A Crimes against the person              int64
# 2015_B Property and deception offences        int64
# 2015_C Drug offences                          int64
#                                               ...
# 2024_D Public order and security offences     int64
# 2024_E Justice procedures offences            int64
# 2024_F Other offences                         int64
# 2024_total                                    int64
# all_crimes_2015-2024                          int64
# Length: 73, dtype: object

# %%
df.iloc[2].filter(like='A Crimes against the person')
# Out:
# 2015_A Crimes against the person    6
# 2016_A Crimes against the person    8
# 2017_A Crimes against the person    8
# 2018_A Crimes against the person    7
# 2019_A Crimes against the person    5
# 2020_A Crimes against the person    8
# 2021_A Crimes against the person    8
# 2022_A Crimes against the person    5
# 2023_A Crimes against the person    7
# 2024_A Crimes against the person    7
# Name: 2, dtype: object

# %%
# ensure no missing values before performing ARIMA
df.isna().sum()
# Out:
# suburb_name                                  0
# SAL_CODE_2021                                0
# 2015_A Crimes against the person             0
# 2015_B Property and deception offences       0
# 2015_C Drug offences                         0
#                                             ..
# 2024_D Public order and security offences    0
# 2024_E Justice procedures offences           0
# 2024_F Other offences                        0
# 2024_total                                   0
# all_crimes_2015-2024                         0
# Length: 73, dtype: int64

# %%
# ARIMA the crime data
iteration = 0
# loop through all crime data
for i in df.index:
    sal = df.iloc[i-1]["SAL_CODE_2021"]
    # only perform ARIMA on suburbs that we are studying
    if sal in sal_codes:

        # code results is where we store the ARIMAed data
        code_results = {}
        code_results["SAL_CODE_2021"] = sal
        iteration += 1

        # ARIMA over all crime division data
        for col in crime_types:

            temp_df = df.iloc[i-1].filter(like=col)
            temp_df = pd.to_numeric(temp_df, errors='coerce')
            temp_df = temp_df.dropna()  # Drop rows with NaN in column

            # ARIMA where there is data from more than two years worth of data
            if len(temp_df) > 2:
                forecast_steps = 4

                # Fit and forecast ARIMA model
                model = sm.tsa.ARIMA(temp_df, order=(1, 1, 1))
                model_fit = model.fit()
                forecast = model_fit.forecast(steps=forecast_steps).to_numpy()
            
                # Store forecast results
                for year in range(2025,2029):
                    full_col = str(year) + '_' + col
                    code_results[full_col] = round(float(forecast[year-2025]),3)
                #print(code_results)
            
            # EXCEPTION HANDLING

            # Assume it increases by the same difference (linearly) between the two measures each year
            elif len(temp_df) == 2:
                diff = temp_df.iloc[0]['2024_'+col] - temp_df.iloc[0]['2023'+col] # CHANGE 
                for year in range(2025,2029):
                    full_col = str(year) + '_' + col
                    code_results[full_col] = temp_df.iloc[0]['2024_'+col] + diff*(year-2024)
            # if 1 years of business data avaliable asumme the crime count is constant here
            elif len(temp_df) == 1:
                for year in range(2025,2029):
                    full_col = str(year) + '_' + col
                    code_results[full_col] = temp_df.iloc[0]['2024_'+col]
            # where there is no crime data avaliable we assume there is no businesses here and assign the value 0
            # shouldn't matter as the dataset was very complete anwyay
            else: #len(temp_df) == 0:
                for year in range(2025,2029):
                    code_results[full_col] = 0
        # append this data to the dataframe of all the data
        df = pd.concat([df, pd.DataFrame([code_results])], ignore_index=True)
        print(f"SAL code iteration {iteration} complete")
# Out:
# SAL code iteration 1 complete
# SAL code iteration 2 complete
# SAL code iteration 3 complete
# SAL code iteration 4 complete
# SAL code iteration 5 complete
# SAL code iteration 6 complete
# SAL code iteration 7 complete
# SAL code iteration 8 complete
# SAL code iteration 9 complete
# SAL code iteration 10 complete
# SAL code iteration 11 complete
# SAL code iteration 12 complete
# SAL code iteration 13 complete
# SAL code iteration 14 complete
# SAL code iteration 15 complete
# SAL code iteration 16 complete
# SAL code iteration 17 complete
# SAL code iteration 18 complete
# SAL code iteration 19 complete
# SAL code iteration 20 complete
# SAL code iteration 21 complete
# SAL code iteration 22 complete
# SAL code iteration 23 complete
# SAL code iteration 24 complete
# SAL code iteration 25 complete
# SAL code iteration 26 complete
# SAL code iteration 27 complete
# SAL code iteration 28 complete
# SAL code iteration 29 complete
# SAL code iteration 30 complete
# SAL code iteration 31 complete
# SAL code iteration 32 complete
# SAL code iteration 33 complete
# SAL code iteration 34 complete
# SAL code iteration 35 complete
# SAL code iteration 36 complete
# SAL code iteration 37 complete
# SAL code iteration 38 complete
# SAL code iteration 39 complete
# SAL code iteration 40 complete
# SAL code iteration 41 complete
# SAL code iteration 42 complete
# SAL code iteration 43 complete
# SAL code iteration 44 complete
# SAL code iteration 45 complete
# SAL code iteration 46 complete
# SAL code iteration 47 complete
# SAL code iteration 48 complete
# SAL code iteration 49 complete
# SAL code iteration 50 complete
# SAL code iteration 51 complete
# SAL code iteration 52 complete
# SAL code iteration 53 complete
# SAL code iteration 54 complete
# SAL code iteration 55 complete
# SAL code iteration 56 complete
# SAL code iteration 57 complete
# SAL code iteration 58 complete
# SAL code iteration 59 complete
# SAL code iteration 60 complete
# SAL code iteration 61 complete
# SAL code iteration 62 complete
# SAL code iteration 63 complete
# SAL code iteration 64 complete
# SAL code iteration 65 complete
# SAL code iteration 66 complete
# SAL code iteration 67 complete
# SAL code iteration 68 complete
# SAL code iteration 69 complete
# SAL code iteration 70 complete
# SAL code iteration 71 complete
# SAL code iteration 72 complete
# SAL code iteration 73 complete
# SAL code iteration 74 complete
# SAL code iteration 75 complete
# SAL code iteration 76 complete
# SAL code iteration 77 complete
# SAL code iteration 78 complete
# SAL code iteration 79 complete
# SAL code iteration 80 complete
# SAL code iteration 81 complete
# SAL code iteration 82 complete
# SAL code iteration 83 complete
# SAL code iteration 84 complete
# SAL code iteration 85 complete
# SAL code iteration 86 complete
# SAL code iteration 87 complete
# SAL code iteration 88 complete
# SAL code iteration 89 complete
# SAL code iteration 90 complete
# SAL code iteration 91 complete
# SAL code iteration 92 complete
# SAL code iteration 93 complete
# SAL code iteration 94 complete
# SAL code iteration 95 complete
# SAL code iteration 96 complete
# SAL code iteration 97 complete
# SAL code iteration 98 complete
# SAL code iteration 99 complete
# SAL code iteration 100 complete
# SAL code iteration 101 complete
# SAL code iteration 102 complete
# SAL code iteration 103 complete
# SAL code iteration 104 complete
# SAL code iteration 105 complete
# SAL code iteration 106 complete
# SAL code iteration 107 complete
# SAL code iteration 108 complete
# SAL code iteration 109 complete
# SAL code iteration 110 complete
# SAL code iteration 111 complete
# SAL code iteration 112 complete
# SAL code iteration 113 complete
# SAL code iteration 114 complete
# SAL code iteration 115 complete
# SAL code iteration 116 complete
# SAL code iteration 117 complete
# SAL code iteration 118 complete
# SAL code iteration 119 complete
# SAL code iteration 120 complete
# SAL code iteration 121 complete
# SAL code iteration 122 complete
# SAL code iteration 123 complete
# SAL code iteration 124 complete
# SAL code iteration 125 complete
# SAL code iteration 126 complete
# SAL code iteration 127 complete
# SAL code iteration 128 complete
# SAL code iteration 129 complete
# SAL code iteration 130 complete
# SAL code iteration 131 complete
# SAL code iteration 132 complete
# SAL code iteration 133 complete
# SAL code iteration 134 complete
# SAL code iteration 135 complete
# SAL code iteration 136 complete
# SAL code iteration 137 complete
# SAL code iteration 138 complete
# SAL code iteration 139 complete
# SAL code iteration 140 complete
# SAL code iteration 141 complete
# SAL code iteration 142 complete
# SAL code iteration 143 complete
# SAL code iteration 144 complete
# SAL code iteration 145 complete
# SAL code iteration 146 complete
# SAL code iteration 147 complete
# SAL code iteration 148 complete
# SAL code iteration 149 complete
# SAL code iteration 150 complete
# SAL code iteration 151 complete
# SAL code iteration 152 complete
# SAL code iteration 153 complete
# SAL code iteration 154 complete
# SAL code iteration 155 complete
# SAL code iteration 156 complete
# SAL code iteration 157 complete
# SAL code iteration 158 complete
# SAL code iteration 159 complete
# SAL code iteration 160 complete
# SAL code iteration 161 complete
# SAL code iteration 162 complete
# SAL code iteration 163 complete
# SAL code iteration 164 complete
# SAL code iteration 165 complete
# SAL code iteration 166 complete
# SAL code iteration 167 complete
# SAL code iteration 168 complete
# SAL code iteration 169 complete
# SAL code iteration 170 complete
# SAL code iteration 171 complete
# SAL code iteration 172 complete
# SAL code iteration 173 complete
# SAL code iteration 174 complete
# SAL code iteration 175 complete
# SAL code iteration 176 complete
# SAL code iteration 177 complete
# SAL code iteration 178 complete
# SAL code iteration 179 complete
# SAL code iteration 180 complete
# SAL code iteration 181 complete
# SAL code iteration 182 complete
# SAL code iteration 183 complete
# SAL code iteration 184 complete
# SAL code iteration 185 complete
# SAL code iteration 186 complete
# SAL code iteration 187 complete
# SAL code iteration 188 complete
# SAL code iteration 189 complete
# SAL code iteration 190 complete
# SAL code iteration 191 complete
# SAL code iteration 192 complete
# SAL code iteration 193 complete
# SAL code iteration 194 complete
# SAL code iteration 195 complete
# SAL code iteration 196 complete
# SAL code iteration 197 complete
# SAL code iteration 198 complete
# SAL code iteration 199 complete
# SAL code iteration 200 complete
# SAL code iteration 201 complete
# SAL code iteration 202 complete
# SAL code iteration 203 complete
# SAL code iteration 204 complete
# SAL code iteration 205 complete
# SAL code iteration 206 complete
# SAL code iteration 207 complete
# SAL code iteration 208 complete
# SAL code iteration 209 complete
# SAL code iteration 210 complete
# SAL code iteration 211 complete
# SAL code iteration 212 complete
# SAL code iteration 213 complete
# SAL code iteration 214 complete
# SAL code iteration 215 complete
# SAL code iteration 216 complete
# SAL code iteration 217 complete
# SAL code iteration 218 complete
# SAL code iteration 219 complete
# SAL code iteration 220 complete
# SAL code iteration 221 complete
# SAL code iteration 222 complete
# SAL code iteration 223 complete
# SAL code iteration 224 complete
# SAL code iteration 225 complete
# SAL code iteration 226 complete
# SAL code iteration 227 complete
# SAL code iteration 228 complete
# SAL code iteration 229 complete
# SAL code iteration 230 complete
# SAL code iteration 231 complete
# SAL code iteration 232 complete
# SAL code iteration 233 complete
# SAL code iteration 234 complete
# SAL code iteration 235 complete
# SAL code iteration 236 complete
# SAL code iteration 237 complete
# SAL code iteration 238 complete
# SAL code iteration 239 complete
# SAL code iteration 240 complete
# SAL code iteration 241 complete
# SAL code iteration 242 complete
# SAL code iteration 243 complete
# SAL code iteration 244 complete
# SAL code iteration 245 complete
# SAL code iteration 246 complete
# SAL code iteration 247 complete
# SAL code iteration 248 complete
# SAL code iteration 249 complete
# SAL code iteration 250 complete
# SAL code iteration 251 complete
# SAL code iteration 252 complete
# SAL code iteration 253 complete
# SAL code iteration 254 complete
# SAL code iteration 255 complete
# SAL code iteration 256 complete
# SAL code iteration 257 complete
# SAL code iteration 258 complete
# SAL code iteration 259 complete
# SAL code iteration 260 complete
# SAL code iteration 261 complete
# SAL code iteration 262 complete
# SAL code iteration 263 complete
# SAL code iteration 264 complete
# SAL code iteration 265 complete
# SAL code iteration 266 complete
# SAL code iteration 267 complete
# SAL code iteration 268 complete
# SAL code iteration 269 complete
# SAL code iteration 270 complete
# SAL code iteration 271 complete
# SAL code iteration 272 complete
# SAL code iteration 273 complete
# SAL code iteration 274 complete
# SAL code iteration 275 complete
# SAL code iteration 276 complete
# SAL code iteration 277 complete
# SAL code iteration 278 complete
# SAL code iteration 279 complete
# SAL code iteration 280 complete
# SAL code iteration 281 complete
# SAL code iteration 282 complete
# SAL code iteration 283 complete
# SAL code iteration 284 complete
# SAL code iteration 285 complete
# SAL code iteration 286 complete
# SAL code iteration 287 complete
# SAL code iteration 288 complete
# SAL code iteration 289 complete
# SAL code iteration 290 complete
# SAL code iteration 291 complete
# SAL code iteration 292 complete
# SAL code iteration 293 complete
# SAL code iteration 294 complete
# SAL code iteration 295 complete
# SAL code iteration 296 complete
# SAL code iteration 297 complete
# SAL code iteration 298 complete
# SAL code iteration 299 complete
# SAL code iteration 300 complete
# SAL code iteration 301 complete
# SAL code iteration 302 complete
# SAL code iteration 303 complete
# SAL code iteration 304 complete
# SAL code iteration 305 complete
# SAL code iteration 306 complete
# SAL code iteration 307 complete
# SAL code iteration 308 complete
# SAL code iteration 309 complete
# SAL code iteration 310 complete
# SAL code iteration 311 complete
# SAL code iteration 312 complete
# SAL code iteration 313 complete
# SAL code iteration 314 complete
# SAL code iteration 315 complete
# SAL code iteration 316 complete
# SAL code iteration 317 complete
# SAL code iteration 318 complete
# SAL code iteration 319 complete
# SAL code iteration 320 complete
# SAL code iteration 321 complete
# SAL code iteration 322 complete
# SAL code iteration 323 complete
# SAL code iteration 324 complete
# SAL code iteration 325 complete
# SAL code iteration 326 complete
# SAL code iteration 327 complete
# SAL code iteration 328 complete
# SAL code iteration 329 complete
# SAL code iteration 330 complete
# SAL code iteration 331 complete
# SAL code iteration 332 complete
# SAL code iteration 333 complete
# SAL code iteration 334 complete
# SAL code iteration 335 complete
# SAL code iteration 336 complete
# SAL code iteration 337 complete
# SAL code iteration 338 complete
# SAL code iteration 339 complete
# SAL code iteration 340 complete
# SAL code iteration 341 complete
# SAL code iteration 342 complete
# SAL code iteration 343 complete
# SAL code iteration 344 complete
# SAL code iteration 345 complete
# SAL code iteration 346 complete
# SAL code iteration 347 complete
# SAL code iteration 348 complete
# SAL code iteration 349 complete
# SAL code iteration 350 complete
# SAL code iteration 351 complete
# SAL code iteration 352 complete
# SAL code iteration 353 complete
# SAL code iteration 354 complete
# SAL code iteration 355 complete
# SAL code iteration 356 complete
# SAL code iteration 357 complete
# SAL code iteration 358 complete
# SAL code iteration 359 complete
# SAL code iteration 360 complete
# SAL code iteration 361 complete
# SAL code iteration 362 complete
# SAL code iteration 363 complete
# SAL code iteration 364 complete
# SAL code iteration 365 complete
# SAL code iteration 366 complete
# SAL code iteration 367 complete
# SAL code iteration 368 complete
# SAL code iteration 369 complete
# SAL code iteration 370 complete
# SAL code iteration 371 complete
# SAL code iteration 372 complete
# SAL code iteration 373 complete
# SAL code iteration 374 complete
# SAL code iteration 375 complete
# SAL code iteration 376 complete
# SAL code iteration 377 complete
# SAL code iteration 378 complete
# SAL code iteration 379 complete
# SAL code iteration 380 complete
# SAL code iteration 381 complete
# SAL code iteration 382 complete
# SAL code iteration 383 complete
# SAL code iteration 384 complete
# SAL code iteration 385 complete
# SAL code iteration 386 complete
# SAL code iteration 387 complete
# SAL code iteration 388 complete
# SAL code iteration 389 complete
# SAL code iteration 390 complete
# SAL code iteration 391 complete
# SAL code iteration 392 complete
# SAL code iteration 393 complete
# SAL code iteration 394 complete
# SAL code iteration 395 complete
# SAL code iteration 396 complete
# SAL code iteration 397 complete
# SAL code iteration 398 complete
# SAL code iteration 399 complete
# SAL code iteration 400 complete
# SAL code iteration 401 complete
# SAL code iteration 402 complete
# SAL code iteration 403 complete
# SAL code iteration 404 complete
# SAL code iteration 405 complete
# SAL code iteration 406 complete
# SAL code iteration 407 complete
# SAL code iteration 408 complete
# SAL code iteration 409 complete
# SAL code iteration 410 complete
# SAL code iteration 411 complete
# SAL code iteration 412 complete
# SAL code iteration 413 complete
# SAL code iteration 414 complete
# SAL code iteration 415 complete
# SAL code iteration 416 complete
# SAL code iteration 417 complete
# SAL code iteration 418 complete
# SAL code iteration 419 complete
# SAL code iteration 420 complete
# SAL code iteration 421 complete
# SAL code iteration 422 complete
# SAL code iteration 423 complete
# SAL code iteration 424 complete
# SAL code iteration 425 complete
# SAL code iteration 426 complete
# SAL code iteration 427 complete
# SAL code iteration 428 complete
# SAL code iteration 429 complete
# SAL code iteration 430 complete
# SAL code iteration 431 complete
# SAL code iteration 432 complete
# SAL code iteration 433 complete
# SAL code iteration 434 complete
# SAL code iteration 435 complete
# SAL code iteration 436 complete
# SAL code iteration 437 complete
# SAL code iteration 438 complete
# SAL code iteration 439 complete
# SAL code iteration 440 complete
# SAL code iteration 441 complete
# SAL code iteration 442 complete
# SAL code iteration 443 complete
# SAL code iteration 444 complete
# SAL code iteration 445 complete
# SAL code iteration 446 complete
# SAL code iteration 447 complete
# SAL code iteration 448 complete
# SAL code iteration 449 complete
# SAL code iteration 450 complete
# SAL code iteration 451 complete
# SAL code iteration 452 complete
# SAL code iteration 453 complete
# SAL code iteration 454 complete
# SAL code iteration 455 complete
# SAL code iteration 456 complete
# SAL code iteration 457 complete
# SAL code iteration 458 complete
# SAL code iteration 459 complete
# SAL code iteration 460 complete
# SAL code iteration 461 complete
# SAL code iteration 462 complete
# SAL code iteration 463 complete
# SAL code iteration 464 complete
# SAL code iteration 465 complete
# SAL code iteration 466 complete
# SAL code iteration 467 complete
# SAL code iteration 468 complete
# SAL code iteration 469 complete
# SAL code iteration 470 complete
# SAL code iteration 471 complete
# SAL code iteration 472 complete
# SAL code iteration 473 complete
# SAL code iteration 474 complete
# SAL code iteration 475 complete
# SAL code iteration 476 complete
# SAL code iteration 477 complete
# SAL code iteration 478 complete
# SAL code iteration 479 complete
# SAL code iteration 480 complete
# SAL code iteration 481 complete
# SAL code iteration 482 complete
# SAL code iteration 483 complete
# SAL code iteration 484 complete
# SAL code iteration 485 complete
# SAL code iteration 486 complete
# SAL code iteration 487 complete
# SAL code iteration 488 complete
# SAL code iteration 489 complete
# SAL code iteration 490 complete
# SAL code iteration 491 complete
# SAL code iteration 492 complete
# SAL code iteration 493 complete
# SAL code iteration 494 complete
# SAL code iteration 495 complete
# SAL code iteration 496 complete
# SAL code iteration 497 complete
# SAL code iteration 498 complete
# SAL code iteration 499 complete
# SAL code iteration 500 complete
# SAL code iteration 501 complete
# SAL code iteration 502 complete
# SAL code iteration 503 complete
# SAL code iteration 504 complete
# SAL code iteration 505 complete
# SAL code iteration 506 complete
# SAL code iteration 507 complete
# SAL code iteration 508 complete
# SAL code iteration 509 complete
# SAL code iteration 510 complete
# SAL code iteration 511 complete
# SAL code iteration 512 complete
# SAL code iteration 513 complete
# SAL code iteration 514 complete
# SAL code iteration 515 complete
# SAL code iteration 516 complete
# SAL code iteration 517 complete
# SAL code iteration 518 complete
# SAL code iteration 519 complete
# SAL code iteration 520 complete
# SAL code iteration 521 complete
# SAL code iteration 522 complete
# SAL code iteration 523 complete
# SAL code iteration 524 complete
# SAL code iteration 525 complete
# SAL code iteration 526 complete
# SAL code iteration 527 complete
# SAL code iteration 528 complete
# SAL code iteration 529 complete
# SAL code iteration 530 complete
# SAL code iteration 531 complete
# SAL code iteration 532 complete
# SAL code iteration 533 complete
# SAL code iteration 534 complete
# SAL code iteration 535 complete
# SAL code iteration 536 complete
# SAL code iteration 537 complete
# SAL code iteration 538 complete
# SAL code iteration 539 complete
# SAL code iteration 540 complete
# SAL code iteration 541 complete
# SAL code iteration 542 complete
# SAL code iteration 543 complete
# SAL code iteration 544 complete
# SAL code iteration 545 complete
# SAL code iteration 546 complete
# SAL code iteration 547 complete
# SAL code iteration 548 complete
# SAL code iteration 549 complete
# SAL code iteration 550 complete
# SAL code iteration 551 complete
# SAL code iteration 552 complete
# SAL code iteration 553 complete
# SAL code iteration 554 complete
# SAL code iteration 555 complete
# SAL code iteration 556 complete
# SAL code iteration 557 complete
# SAL code iteration 558 complete
# SAL code iteration 559 complete
# SAL code iteration 560 complete
# SAL code iteration 561 complete
# SAL code iteration 562 complete
# SAL code iteration 563 complete
# SAL code iteration 564 complete
# SAL code iteration 565 complete
# SAL code iteration 566 complete
# SAL code iteration 567 complete

# %%
df
# Out:
#      suburb_name  SAL_CODE_2021  2015_A Crimes against the person  \
# 0       Abbeyard          20001                               0.0
# 1     Abbotsford          20002                              10.0
# 2     Aberfeldie          20003                               6.0
# 3      Aberfeldy          20004                               0.0
# 4        Acheron          20005                               1.0
# ...          ...            ...                               ...
# 3409         NaN          22916                               NaN
# 3410         NaN          22917                               NaN
# 3411         NaN          22925                               NaN
# 3412         NaN          22930                               NaN
# 3413         NaN          22941                               NaN
#
#       2015_B Property and deception offences  2015_C Drug offences  \
# 0                                        0.0                   0.0
# 1                                       18.0                   3.0
# 2                                       11.0                   2.0
# 3                                        0.0                   0.0
# 4                                        1.0                   0.0
# ...                                      ...                   ...
# 3409                                     NaN                   NaN
# 3410                                     NaN                   NaN
# 3411                                     NaN                   NaN
# 3412                                     NaN                   NaN
# 3413                                     NaN                   NaN
#
#       2015_D Public order and security offences  \
# 0                                           1.0
# 1                                           7.0
# 2                                           0.0
# 3                                           0.0
# 4                                           0.0
# ...                                         ...
# 3409                                        NaN
# 3410                                        NaN
# 3411                                        NaN
# 3412                                        NaN
# 3413                                        NaN
#
#       2015_E Justice procedures offences  2015_F Other offences  2015_total  \
# 0                                    0.0                    1.0         2.0
# 1                                    4.0                    0.0        42.0
# 2                                    1.0                    0.0        20.0
# 3                                    0.0                    1.0         1.0
# 4                                    0.0                    0.0         2.0
# ...                                  ...                    ...         ...
# 3409                                 NaN                    NaN         NaN
# 3410                                 NaN                    NaN         NaN
# 3411                                 NaN                    NaN         NaN
# 3412                                 NaN                    NaN         NaN
# 3413                                 NaN                    NaN         NaN
#
#       2016_A Crimes against the person  ...  \
# 0                                  0.0  ...
# 1                                 13.0  ...
# 2                                  8.0  ...
# 3                                  0.0  ...
# 4                                  0.0  ...
# ...                                ...  ...
# 3409                               NaN  ...
# 3410                               NaN  ...
# 3411                               NaN  ...
# 3412                               NaN  ...
# 3413                               NaN  ...
#
#       2027_D Public order and security offences  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 3409                                      1.837
# 3410                                      7.084
# 3411                                      0.000
# 3412                                      0.399
# 3413                                      1.318
#
#       2028_D Public order and security offences  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 3409                                      1.830
# 3410                                      7.156
# 3411                                      0.000
# 3412                                      0.399
# 3413                                      1.290
#
#       2025_E Justice procedures offences  2026_E Justice procedures offences  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 3409                               1.104                               1.120
# 3410                               5.666                               5.465
# 3411                               1.050                               0.000
# 3412                               0.258                               0.288
# 3413                               1.210                               1.195
#
#       2027_E Justice procedures offences  2028_E Justice procedures offences  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 3409                               1.123                               1.123
# 3410                               5.344                               5.271
# 3411                               1.050                               0.000
# 3412                               0.292                               0.292
# 3413                               1.196                               1.196
#
#       2025_F Other offences  2026_F Other offences  2027_F Other offences  \
# 0                       NaN                    NaN                    NaN
# 1                       NaN                    NaN                    NaN
# 2                       NaN                    NaN                    NaN
# 3                       NaN                    NaN                    NaN
# 4                       NaN                    NaN                    NaN
# ...                     ...                    ...                    ...
# 3409                 -0.000                 -0.000                 -0.000
# 3410                  1.159                  1.239                  1.278
# 3411                  0.245                  0.199                  0.208
# 3412                 -0.000                 -0.000                 -0.000
# 3413                  0.103                  0.100                  0.100
#
#       2028_F Other offences
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 3409                 -0.000
# 3410                  1.298
# 3411                  0.206
# 3412                 -0.000
# 3413                  0.100
#
# [3414 rows x 97 columns]

# %%
# here we group by the dataframe on the to reduced the no. columns and get rid of all the NaN columns
# we also filter out any suburbs/towns irrelevant to the study
df = df.fillna(0) 
df = df.drop(columns="suburb_name")
df = df[df["SAL_CODE_2021"].isin(sal_codes)]
grouped_df = df.groupby('SAL_CODE_2021').sum()
grouped_df
# Out:
#                2015_A Crimes against the person  \
# SAL_CODE_2021
# 20002                                      10.0
# 20003                                       6.0
# 20011                                       0.0
# 20015                                      11.0
# 20017                                      11.0
# ...                                         ...
# 22916                                       3.0
# 22917                                      13.0
# 22925                                       1.0
# 22930                                       0.0
# 22941                                       1.0
#
#                2015_B Property and deception offences  2015_C Drug offences  \
# SAL_CODE_2021
# 20002                                            18.0                   3.0
# 20003                                            11.0                   2.0
# 20011                                             4.0                   0.0
# 20015                                            16.0                   5.0
# 20017                                            16.0                   5.0
# ...                                               ...                   ...
# 22916                                            10.0                   1.0
# 22917                                            16.0                   3.0
# 22925                                             7.0                   1.0
# 22930                                             4.0                   0.0
# 22941                                             7.0                   0.0
#
#                2015_D Public order and security offences  \
# SAL_CODE_2021
# 20002                                                7.0
# 20003                                                0.0
# 20011                                                0.0
# 20015                                                8.0
# 20017                                                4.0
# ...                                                  ...
# 22916                                                2.0
# 22917                                                5.0
# 22925                                                2.0
# 22930                                                0.0
# 22941                                                0.0
#
#                2015_E Justice procedures offences  2015_F Other offences  \
# SAL_CODE_2021
# 20002                                         4.0                    0.0
# 20003                                         1.0                    0.0
# 20011                                         0.0                    0.0
# 20015                                         2.0                    1.0
# 20017                                         2.0                    0.0
# ...                                           ...                    ...
# 22916                                         2.0                    0.0
# 22917                                         4.0                    2.0
# 22925                                         2.0                    0.0
# 22930                                         0.0                    0.0
# 22941                                         2.0                    0.0
#
#                2015_total  2016_A Crimes against the person  \
# SAL_CODE_2021
# 20002                42.0                              13.0
# 20003                20.0                               8.0
# 20011                 4.0                               2.0
# 20015                43.0                              15.0
# 20017                38.0                              10.0
# ...                   ...                               ...
# 22916                18.0                               4.0
# 22917                43.0                              12.0
# 22925                13.0                               3.0
# 22930                 4.0                               2.0
# 22941                10.0                               1.0
#
#                2016_B Property and deception offences  2016_C Drug offences  \
# SAL_CODE_2021
# 20002                                            16.0                   3.0
# 20003                                            11.0                   2.0
# 20011                                             5.0                   0.0
# 20015                                            16.0                   5.0
# 20017                                            16.0                   3.0
# ...                                               ...                   ...
# 22916                                            10.0                   1.0
# 22917                                            15.0                   3.0
# 22925                                             6.0                   2.0
# 22930                                             3.0                   0.0
# 22941                                             5.0                   0.0
#
#                ...  2027_D Public order and security offences  \
# SAL_CODE_2021  ...
# 20002          ...                                      8.092
# 20003          ...                                      1.921
# 20011          ...                                      3.504
# 20015          ...                                      5.915
# 20017          ...                                      3.715
# ...            ...                                        ...
# 22916          ...                                      1.837
# 22917          ...                                      7.084
# 22925          ...                                      0.000
# 22930          ...                                      0.399
# 22941          ...                                      1.318
#
#                2028_D Public order and security offences  \
# SAL_CODE_2021
# 20002                                              8.029
# 20003                                              1.921
# 20011                                              3.344
# 20015                                              5.851
# 20017                                              3.736
# ...                                                  ...
# 22916                                              1.830
# 22917                                              7.156
# 22925                                              0.000
# 22930                                              0.399
# 22941                                              1.290
#
#                2025_E Justice procedures offences  \
# SAL_CODE_2021
# 20002                                       5.575
# 20003                                       2.446
# 20011                                       4.977
# 20015                                       5.955
# 20017                                       4.912
# ...                                           ...
# 22916                                       1.104
# 22917                                       5.666
# 22925                                       1.050
# 22930                                       0.258
# 22941                                       1.210
#
#                2026_E Justice procedures offences  \
# SAL_CODE_2021
# 20002                                       5.613
# 20003                                       2.320
# 20011                                       4.975
# 20015                                       7.000
# 20017                                       4.954
# ...                                           ...
# 22916                                       1.120
# 22917                                       5.465
# 22925                                       0.000
# 22930                                       0.288
# 22941                                       1.195
#
#                2027_E Justice procedures offences  \
# SAL_CODE_2021
# 20002                                       5.610
# 20003                                       2.292
# 20011                                       4.975
# 20015                                       5.955
# 20017                                       4.934
# ...                                           ...
# 22916                                       1.123
# 22917                                       5.344
# 22925                                       1.050
# 22930                                       0.292
# 22941                                       1.196
#
#                2028_E Justice procedures offences  2025_F Other offences  \
# SAL_CODE_2021
# 20002                                       5.610                  0.873
# 20003                                       2.285                  0.103
# 20011                                       4.975                  0.103
# 20015                                       7.000                  0.587
# 20017                                       4.944                  0.546
# ...                                           ...                    ...
# 22916                                       1.123                  0.000
# 22917                                       5.271                  1.159
# 22925                                       0.000                  0.245
# 22930                                       0.292                  0.000
# 22941                                       1.196                  0.103
#
#                2026_F Other offences  2027_F Other offences  \
# SAL_CODE_2021
# 20002                          0.878                  0.878
# 20003                          0.100                  0.100
# 20011                          0.100                  0.100
# 20015                          0.599                  0.600
# 20017                          0.504                  0.507
# ...                              ...                    ...
# 22916                          0.000                  0.000
# 22917                          1.239                  1.278
# 22925                          0.199                  0.208
# 22930                          0.000                  0.000
# 22941                          0.100                  0.100
#
#                2028_F Other offences
# SAL_CODE_2021
# 20002                          0.878
# 20003                          0.100
# 20011                          0.100
# 20015                          0.600
# 20017                          0.507
# ...                              ...
# 22916                          0.000
# 22917                          1.298
# 22925                          0.206
# 22930                          0.000
# 22941                          0.100
#
# [567 rows x 95 columns]

# %%
# output the df
output_df = grouped_df
# counts can't below 0
output_df[output_df <= 0] = 0
print(output_df.shape)
output_df.to_csv(f"../../data/curated/crime_2015-2028.csv")
# Out:
# (567, 95)
