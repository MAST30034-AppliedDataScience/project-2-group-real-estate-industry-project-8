# %% [markdown]
# # Suburb Proximity Preprocessing Part 1: Data Aggregation
#
# In this notebook the data is aggregated and prepared so proximity data of train stations and distance to the CBD can be computed. Distance and time measures are measured by kilometers and seconds as travelled by car on the most direct route to given the destination from the center of the suburb in question.
#
# Sections:
# 1. Train Data Aggregation
# 2. Feature Engineering
#
#     2.1 No. Stations in a Suburb
#
#     2.2 Suburb Centres
#
#     2.3 Two Closest Stations

# %%
import pandas as pd
import numpy as np
import re
import geopandas as gpd
from shapely.geometry import Point, Polygon
import folium

# define constants
CBD_LAT = -37.8124
CBD_LNG = 144.962646

# %% [markdown]
# ### 1 Train Data Aggregation
# Gather all train station data into one dataset

# %%
# read in first train dataset - metropolitan stations
metropolitan_trains_df = pd.read_csv("../../data/landing/Annual_Metropolitan_Train_Station_Entries_2023-24.csv")
metropolitan_trains_df
# Out:
#     Fin_year  Stop_ID      Stop_name   Stop_lat   Stop_long  Pax_annual  \
# 0    FY23-24    19829       Morradoo -38.354033  145.189603        3600
# 1    FY23-24    19831       Hastings -38.305659  145.185980       14300
# 2    FY23-24    19832          Tyabb -38.259815  145.186401        3250
# 3    FY23-24    19833     Somerville -38.225342  145.176245        7400
# 4    FY23-24    19835      Glen Iris -37.859308  145.058225      268850
# ..       ...      ...            ...        ...         ...         ...
# 217  FY23-24    19836       Leawarra -38.152034  145.139534        5150
# 218  FY23-24    20028    Showgrounds -37.783500  144.915000      138000
# 219  FY23-24    19834         Baxter -38.194043  145.160526        2550
# 220  FY23-24    19942     Glenhuntly -37.889719  145.042223      524650
# 221  FY23-24    49458  East Pakenham -38.084284  145.506311        3700
#
#      Pax_weekday  Pax_norm_weekday  Pax_sch_hol_weekday  Pax_Saturday  \
# 0             50                50                   50            50
# 1             50                50                   50            50
# 2             50                50                   50            50
# 3             50                50                   50            50
# 4            850               900                  650           550
# ..           ...               ...                  ...           ...
# 217           50                50                   50            50
# 218          250                50                 1150           650
# 219           50                50                   50            50
# 220         1600              1650                 1450          1200
# 221           50                50                   50            50
#
#      Pax_Sunday  Pax_pre_AM_peak  Pax_AM_peak  Pax_interpeak  Pax_PM_peak  \
# 0            50               50           50             50           50
# 1            50               50           50             50           50
# 2            50               50           50             50           50
# 3            50               50           50             50           50
# 4           350               50          400            150          250
# ..          ...              ...          ...            ...          ...
# 217          50               50           50             50           50
# 218         500               50           50             50           50
# 219          50               50           50             50           50
# 220         850              100          700            400          350
# 221          50               50           50             50           50
#
#      Pax_PM_late
# 0             50
# 1             50
# 2             50
# 3             50
# 4             50
# ..           ...
# 217           50
# 218           50
# 219           50
# 220          100
# 221           50
#
# [222 rows x 16 columns]

# %%
# extract relevant data
metropolitan_trains_df = pd.DataFrame(data=metropolitan_trains_df, columns=["Stop_name", "Stop_lat", "Stop_long"])
metropolitan_trains_df = metropolitan_trains_df.rename(columns={"Stop_name": "STOP_NAME", 
                                                                "Stop_lat": "LATITUDE", 
                                                                "Stop_long": "LONGITUDE"
                                                                })
metropolitan_trains_df
# Out:
#          STOP_NAME   LATITUDE   LONGITUDE
# 0         Morradoo -38.354033  145.189603
# 1         Hastings -38.305659  145.185980
# 2            Tyabb -38.259815  145.186401
# 3       Somerville -38.225342  145.176245
# 4        Glen Iris -37.859308  145.058225
# ..             ...        ...         ...
# 217       Leawarra -38.152034  145.139534
# 218    Showgrounds -37.783500  144.915000
# 219         Baxter -38.194043  145.160526
# 220     Glenhuntly -37.889719  145.042223
# 221  East Pakenham -38.084284  145.506311
#
# [222 rows x 3 columns]

# %%
# read in second train dataset - regional stations
trains_regional_gdf = gpd.read_file(
    "../../data/landing/Order_L8LCPT/gda2020_vicgrid/esrishape/whole_of_dataset/victoria/PTV/PTV_REGIONAL_TRAIN_STATION.shp"
    )
trains_regional_gdf
# Out:
#     STOP_ID   LATITUDE                                     STOP_NAME  \
# 0     17204 -37.416861               Wallan Railway Station (Wallan)
# 1     19980 -37.703359         Melton Railway Station (Melton South)
# 2     19981 -37.729261           Rockbank Railway Station (Rockbank)
# 3     19982 -37.777764         Deer Park Railway Station (Deer Park)
# 4     19998 -37.579206             Sunbury Railway Station (Sunbury)
# ..      ...        ...                                           ...
# 105   47642 -36.706342                 Epsom Railway Station (Epsom)
# 106   47647 -37.872886    Wyndham Vale Railway Station (Manor Lakes)
# 107   47648 -37.832168             Tarneit Railway Station (Tarneit)
# 108   48804 -37.712546       Cobblebank Railway Station (Cobblebank)
# 109   52011 -37.766145  Caroline Springs Railway Station (Ravenhall)
#
#       LONGITUDE                         geometry
# 0    145.005372  POINT (2500476.019 2453744.181)
# 1    144.572216  POINT (2462279.390 2421864.847)
# 2    144.650631  POINT (2469204.367 2419018.408)
# 3    144.772304  POINT (2479942.450 2413667.849)
# 4    144.728165  POINT (2475991.284 2435693.792)
# ..          ...                              ...
# 105  144.321040  POINT (2439342.475 2532369.037)
# 106  144.608732  POINT (2465576.596 2403063.717)
# 107  144.694714  POINT (2473126.809 2407610.618)
# 108  144.604108  POINT (2465095.788 2420857.422)
# 109  144.735748  POINT (2476718.590 2414949.062)
#
# [110 rows x 5 columns]

# %%
# rename stop name in the trains_regional_gdf so that the station names match up
station_in_brackets = [re.search(r'\(([^()]+)', station).group(1).strip() for station in trains_regional_gdf["STOP_NAME"]]
sorted(station_in_brackets)
trains_regional_gdf["STOP_NAME"] = station_in_brackets
trains_regional_gdf
# Out:
#     STOP_ID   LATITUDE     STOP_NAME   LONGITUDE  \
# 0     17204 -37.416861        Wallan  145.005372
# 1     19980 -37.703359  Melton South  144.572216
# 2     19981 -37.729261      Rockbank  144.650631
# 3     19982 -37.777764     Deer Park  144.772304
# 4     19998 -37.579206       Sunbury  144.728165
# ..      ...        ...           ...         ...
# 105   47642 -36.706342         Epsom  144.321040
# 106   47647 -37.872886   Manor Lakes  144.608732
# 107   47648 -37.832168       Tarneit  144.694714
# 108   48804 -37.712546    Cobblebank  144.604108
# 109   52011 -37.766145     Ravenhall  144.735748
#
#                             geometry
# 0    POINT (2500476.019 2453744.181)
# 1    POINT (2462279.390 2421864.847)
# 2    POINT (2469204.367 2419018.408)
# 3    POINT (2479942.450 2413667.849)
# 4    POINT (2475991.284 2435693.792)
# ..                               ...
# 105  POINT (2439342.475 2532369.037)
# 106  POINT (2465576.596 2403063.717)
# 107  POINT (2473126.809 2407610.618)
# 108  POINT (2465095.788 2420857.422)
# 109  POINT (2476718.590 2414949.062)
#
# [110 rows x 5 columns]

# %%
# Merging the DataFrames
trains_merged_df = pd.merge(trains_regional_gdf, metropolitan_trains_df, on="STOP_NAME", suffixes=('_df1', '_df2'), how='outer')

# Choose lat and long from df1 if they are different
trains_merged_df["LATITUDE"] = trains_merged_df.apply(lambda row: row["LATITUDE_df1"] \
    if pd.notna(row["LATITUDE_df1"]) else row["LATITUDE_df2"], axis=1)
trains_merged_df["LONGITUDE"] = trains_merged_df.apply(lambda row: row["LONGITUDE_df1"] \
    if pd.notna(row["LONGITUDE_df1"]) else row["LONGITUDE_df2"], axis=1)

# Dropping the extra columns from the merge
trains_merged_df = trains_merged_df[["STOP_NAME","LATITUDE","LONGITUDE",]]
trains_merged_df
# Out:
#       STOP_NAME   LATITUDE   LONGITUDE
# 0      Aircraft -37.866606  144.760809
# 1       Alamein -37.868320  145.079656
# 2        Albion -37.777653  144.824704
# 3        Albury -36.084262  146.924515
# 4    Alphington -37.778394  145.031255
# ..          ...        ...         ...
# 316     Wodonga -36.105827  146.871266
# 317     Woodend -37.358799  144.525890
# 318    Yarragon -38.203158  146.063063
# 319    Yarraman -37.978255  145.191600
# 320  Yarraville -37.815850  144.889934
#
# [321 rows x 3 columns]

# %%
# drop stations that are repeated entries or outside of victoria
trains_merged_df = trains_merged_df.drop(trains_merged_df[trains_merged_df["STOP_NAME"]=="Melbourne City"].index[0])
trains_merged_df = trains_merged_df.drop(trains_merged_df[trains_merged_df["STOP_NAME"]=="Melbourne City"].index[0])
trains_merged_df = trains_merged_df.drop(trains_merged_df[trains_merged_df["STOP_NAME"]=="Albury"].index[0])
trains_merged_df
# Out:
#       STOP_NAME   LATITUDE   LONGITUDE
# 0      Aircraft -37.866606  144.760809
# 1       Alamein -37.868320  145.079656
# 2        Albion -37.777653  144.824704
# 4    Alphington -37.778394  145.031255
# 5        Altona -37.867148  144.829645
# ..          ...        ...         ...
# 316     Wodonga -36.105827  146.871266
# 317     Woodend -37.358799  144.525890
# 318    Yarragon -38.203158  146.063063
# 319    Yarraman -37.978255  145.191600
# 320  Yarraville -37.815850  144.889934
#
# [318 rows x 3 columns]

# %% [markdown]
# ### 2 Feature Engineering

# %% [markdown]
# #### 2.2 No. Stations in a Suburb

# %%
# Read in SAL boundaries as supplied by the ABS dataset
SAL_gdf = gpd.read_file("../../data/landing/SAL_data/SAL_2021_AUST_GDA2020.shp")
SAL_gdf
# Out:
#       SAL_CODE21                            SAL_NAME21 STE_CODE21  \
# 0          10001                           Aarons Pass          1
# 1          10002                            Abbotsbury          1
# 2          10003                      Abbotsford (NSW)          1
# 3          10004                           Abercrombie          1
# 4          10005                     Abercrombie River          1
# ...          ...                                   ...        ...
# 15348      90004                        Norfolk Island          9
# 15349      90005                           West Island          9
# 15350      99494                 No usual address (OT)          9
# 15351      99797  Migratory - Offshore - Shipping (OT)          9
# 15352      ZZZZZ                     Outside Australia          Z
#
#               STE_NAME21 AUS_CODE21         AUS_NAME21  AREASQKM21  \
# 0        New South Wales        AUS          Australia     82.7639
# 1        New South Wales        AUS          Australia      4.9788
# 2        New South Wales        AUS          Australia      1.0180
# 3        New South Wales        AUS          Australia      2.9775
# 4        New South Wales        AUS          Australia    127.1701
# ...                  ...        ...                ...         ...
# 15348  Other Territories        AUS          Australia     38.6510
# 15349  Other Territories        AUS          Australia      5.9276
# 15350  Other Territories        AUS          Australia      0.0000
# 15351  Other Territories        AUS          Australia      0.0000
# 15352  Outside Australia        ZZZ  Outside Australia      0.0000
#
#                                               LOCI_URI21  SHAPE_Leng  \
# 0      http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.554241
# 1      http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.123051
# 2      http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.053423
# 3      http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.097338
# 4      http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.848903
# ...                                                  ...         ...
# 15348  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.629774
# 15349  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.416115
# 15350  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.000000
# 15351  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.000000
# 15352  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.000000
#
#        SHAPE_Area                                           geometry
# 0        0.007975  POLYGON ((149.82477 -32.84384, 149.83271 -32.8...
# 1        0.000485  POLYGON ((150.86523 -33.88264, 150.86479 -33.8...
# 2        0.000099  POLYGON ((151.13472 -33.85492, 151.13445 -33.8...
# 3        0.000289  POLYGON ((149.55192 -33.39280, 149.55148 -33.3...
# 4        0.012397  POLYGON ((149.25562 -33.96535, 149.25563 -33.9...
# ...           ...                                                ...
# 15348    0.003580  MULTIPOLYGON (((167.94051 -29.06260, 167.94046...
# 15349    0.000492  MULTIPOLYGON (((96.82779 -12.17627, 96.82773 -...
# 15350    0.000000                                               None
# 15351    0.000000                                               None
# 15352    0.000000                                               None
#
# [15353 rows x 11 columns]

# %%
# filter out all non Victorian border
SAL_gdf = SAL_gdf[SAL_gdf["STE_NAME21"]== "Victoria"]
SAL_gdf = SAL_gdf[SAL_gdf["geometry"]!=None] # remove those codes without SAL borders
SAL_gdf = SAL_gdf.rename(columns={"SAL_CODE21": "SAL_CODE_2021"})
SAL_gdf
# Out:
#      SAL_CODE_2021         SAL_NAME21 STE_CODE21 STE_NAME21 AUS_CODE21  \
# 4544         20001           Abbeyard          2   Victoria        AUS
# 4545         20002  Abbotsford (Vic.)          2   Victoria        AUS
# 4546         20003         Aberfeldie          2   Victoria        AUS
# 4547         20004          Aberfeldy          2   Victoria        AUS
# 4548         20005            Acheron          2   Victoria        AUS
# ...            ...                ...        ...        ...        ...
# 7483         22940            Yundool          2   Victoria        AUS
# 7484         22941             Yuroke          2   Victoria        AUS
# 7485         22942            Yuulong          2   Victoria        AUS
# 7486         22943            Zeerust          2   Victoria        AUS
# 7487         22944          Zumsteins          2   Victoria        AUS
#
#      AUS_NAME21  AREASQKM21  \
# 4544  Australia    327.5008
# 4545  Australia      1.7405
# 4546  Australia      1.5515
# 4547  Australia     10.8319
# 4548  Australia     72.6602
# ...         ...         ...
# 7483  Australia     31.6396
# 7484  Australia      8.8851
# 7485  Australia     52.1657
# 7486  Australia     18.0294
# 7487  Australia    256.5582
#
#                                              LOCI_URI21  SHAPE_Leng  \
# 4544  http://linked.data.gov.au/dataset/asgsed3/SAL/...    1.207678
# 4545  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.092990
# 4546  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.059374
# 4547  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.183199
# 4548  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.514040
# ...                                                 ...         ...
# 7483  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.256626
# 7484  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.158951
# 7485  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.447416
# 7486  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.211342
# 7487  http://linked.data.gov.au/dataset/asgsed3/SAL/...    0.810459
#
#       SHAPE_Area                                           geometry
# 4544    0.033162  POLYGON ((146.89824 -37.04602, 146.89947 -37.0...
# 4545    0.000178  POLYGON ((145.00195 -37.79665, 145.00190 -37.7...
# 4546    0.000159  POLYGON ((144.89576 -37.76514, 144.89547 -37.7...
# 4547    0.001107  POLYGON ((146.38814 -37.72232, 146.38808 -37.7...
# 4548    0.007381  POLYGON ((145.76731 -37.25433, 145.76757 -37.2...
# ...          ...                                                ...
# 7483    0.003174  POLYGON ((145.86040 -36.28432, 145.86038 -36.2...
# 7484    0.000906  POLYGON ((144.85250 -37.55800, 144.85303 -37.5...
# 7485    0.005404  POLYGON ((143.32185 -38.68969, 143.32203 -38.6...
# 7486    0.001808  POLYGON ((145.40454 -36.25294, 145.40479 -36.2...
# 7487    0.026011  POLYGON ((142.48512 -37.15733, 142.48443 -37.1...
#
# [2944 rows x 11 columns]

# %%
SAL_geoJSON = SAL_gdf.to_json()

# %%
# create map of SAL borders
sal_map = folium.Map(location=[CBD_LAT, CBD_LNG], zoom_start=10)

sal_map.add_child(folium.Choropleth(
    geo_data=SAL_geoJSON,
    name="choropleth",
    fill_color="green",
))
for _, row in trains_merged_df.iterrows():
    folium.Marker(
        location=[row["LATITUDE"], row["LONGITUDE"]],
        popup=row["STOP_NAME"],
        icon=folium.Icon(color="blue")  # Set marker color
    ).add_to(sal_map)

# %%
# Convert the DataFrame of station coordinates to a GeoDataFrame
geometry = [Point(xy) for xy in zip(trains_merged_df['LONGITUDE'], trains_merged_df['LATITUDE'])]
trains_gdf = gpd.GeoDataFrame(trains_merged_df, geometry=geometry, crs="EPSG:4326")

trains_gdf
# Out:
#       STOP_NAME   LATITUDE   LONGITUDE                     geometry
# 0      Aircraft -37.866606  144.760809  POINT (144.76081 -37.86661)
# 1       Alamein -37.868320  145.079656  POINT (145.07966 -37.86832)
# 2        Albion -37.777653  144.824704  POINT (144.82470 -37.77765)
# 4    Alphington -37.778394  145.031255  POINT (145.03125 -37.77839)
# 5        Altona -37.867148  144.829645  POINT (144.82964 -37.86715)
# ..          ...        ...         ...                          ...
# 316     Wodonga -36.105827  146.871266  POINT (146.87127 -36.10583)
# 317     Woodend -37.358799  144.525890  POINT (144.52589 -37.35880)
# 318    Yarragon -38.203158  146.063063  POINT (146.06306 -38.20316)
# 319    Yarraman -37.978255  145.191600  POINT (145.19160 -37.97825)
# 320  Yarraville -37.815850  144.889934  POINT (144.88993 -37.81585)
#
# [318 rows x 4 columns]

# %%
# Perform a spatial join to find stations within all SAL suburbs
points_within_polygons = gpd.sjoin(trains_gdf, SAL_gdf, how="inner", op='within')

# Count how many stations that fall within each SAL suburb
polygon_point_counts = points_within_polygons.groupby('index_right').size()

polygon_point_counts
# Out:
# /Users/zacpathak/opt/anaconda3/envs/mast30034_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/dy/529c1fmn5nv__cgj0j36sm1m0000gn/T/ipykernel_89544/4194727272.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: EPSG:7844
#
#   points_within_polygons = gpd.sjoin(trains_gdf, SAL_gdf, how="inner", op='within')
# index_right
# 4545    2
# 4564    1
# 4577    1
# 4578    2
# 4596    1
#        ..
# 7348    1
# 7362    1
# 7376    1
# 7456    1
# 7460    1
# Length: 244, dtype: int64

# %%
# append number of stations in each suburb to the SAL gdf
SAL_gdf['station_count_in_suburb'] = polygon_point_counts
SAL_gdf['station_count_in_suburb'] = SAL_gdf['station_count_in_suburb'].fillna(0)

# %% [markdown]
# #### 2.2 Suburb Centroids

# %%
# read suburbs that centres need to be recorded on
historical_rent_df = pd.read_csv('../../data/curated/historical_rent_cleaned.csv')
historical_rent_df
# Out:
#              Suburb Cluster  SAL_CODE_2021     SAL suburb  \
# 0           Inner Melbourne          20018    Albert Park
# 1           Inner Melbourne          21677    Middle Park
# 2           Inner Melbourne          22345  St Kilda West
# 3           Inner Melbourne          20066       Armadale
# 4           Inner Melbourne          20496  Carlton North
# ..                      ...            ...            ...
# 564  Other Regional Centres          22569      Traralgon
# 565  Other Regional Centres          22680     Wangaratta
# 566  Other Regional Centres          22698       Warragul
# 567  Other Regional Centres          22710    Warrnambool
# 568  Other Regional Centres          22819        Wodonga
#
#                               Suburb Group Mar 2000 Count (of suburb group)  \
# 0    Albert Park-Middle Park-West St Kilda                             1143
# 1    Albert Park-Middle Park-West St Kilda                             1143
# 2    Albert Park-Middle Park-West St Kilda                             1143
# 3                                 Armadale                              733
# 4                            Carlton North                              864
# ..                                     ...                              ...
# 564                              Traralgon                              851
# 565                            Wanagaratta                              705
# 566                               Warragul                              385
# 567                            Warrnambool                             1266
# 568                                Wodonga                             1446
#
#     Mar 2000 Median Jun 2000 Count (of suburb group) Jun 2000 Median  \
# 0               260                             1134             260
# 1               260                             1134             260
# 2               260                             1134             260
# 3               200                              737             200
# 4               260                              814             260
# ..              ...                              ...             ...
# 564             125                              823             120
# 565             125                              671             125
# 566             130                              367             135
# 567             130                             1229             135
# 568             145                             1439             145
#
#     Sep 2000 Count (of suburb group) Sep 2000 Median  ...  \
# 0                               1177             270  ...
# 1                               1177             270  ...
# 2                               1177             270  ...
# 3                                738             205  ...
# 4                                799             265  ...
# ..                               ...             ...  ...
# 564                              831             125  ...
# 565                              631             130  ...
# 566                              382             135  ...
# 567                             1204             135  ...
# 568                             1468             150  ...
#
#     Mar 2023 Count (of suburb group) Mar 2023 Median  \
# 0                                796             545
# 1                                796             545
# 2                                796             545
# 3                                757             490
# 4                                497             620
# ..                               ...             ...
# 564                              919             385
# 565                              535             380
# 566                              507             440
# 567                              881             420
# 568                             1205             410
#
#     Jun 2023 Count (of suburb group) Jun 2023 Median  \
# 0                                740             550
# 1                                740             550
# 2                                740             550
# 3                                687             500
# 4                                495             630
# ..                               ...             ...
# 564                              922             390
# 565                              555             390
# 566                              542             450
# 567                              861             430
# 568                             1187             420
#
#     Sep 2023 Count (of suburb group) Sep 2023 Median  \
# 0                                730             600
# 1                                730             600
# 2                                730             600
# 3                                639             525
# 4                                467             650
# ..                               ...             ...
# 564                              910             390
# 565                              565             390
# 566                              558             450
# 567                              846             450
# 568                             1164             420
#
#     Dec 2023 Count (of suburb group) Dec 2023 Median  \
# 0                                720             600
# 1                                720             600
# 2                                720             600
# 3                                594             560
# 4                                418             670
# ..                               ...             ...
# 564                              880             395
# 565                              593             395
# 566                              543             460
# 567                              844             460
# 568                             1155             430
#
#     Mar 2024 Count (of suburb group) Mar 2024 Median
# 0                                671             650
# 1                                671             650
# 2                                671             650
# 3                                566             560
# 4                                384             680
# ..                               ...             ...
# 564                              842             410
# 565                              580             400
# 566                              541             470
# 567                              840             460
# 568                             1139             450
#
# [569 rows x 198 columns]

# %%
# filter through to the necessary columns
all_suburbs_df = historical_rent_df[["Suburb Cluster", "SAL suburb", "SAL_CODE_2021", "Suburb Group"]]
all_suburbs_df
# Out:
#              Suburb Cluster     SAL suburb  SAL_CODE_2021  \
# 0           Inner Melbourne    Albert Park          20018
# 1           Inner Melbourne    Middle Park          21677
# 2           Inner Melbourne  St Kilda West          22345
# 3           Inner Melbourne       Armadale          20066
# 4           Inner Melbourne  Carlton North          20496
# ..                      ...            ...            ...
# 564  Other Regional Centres      Traralgon          22569
# 565  Other Regional Centres     Wangaratta          22680
# 566  Other Regional Centres       Warragul          22698
# 567  Other Regional Centres    Warrnambool          22710
# 568  Other Regional Centres        Wodonga          22819
#
#                               Suburb Group
# 0    Albert Park-Middle Park-West St Kilda
# 1    Albert Park-Middle Park-West St Kilda
# 2    Albert Park-Middle Park-West St Kilda
# 3                                 Armadale
# 4                            Carlton North
# ..                                     ...
# 564                              Traralgon
# 565                            Wanagaratta
# 566                               Warragul
# 567                            Warrnambool
# 568                                Wodonga
#
# [569 rows x 4 columns]

# %%
# Check and align data types
all_suburbs_df['SAL_CODE_2021'] = all_suburbs_df['SAL_CODE_2021'].astype(str)
SAL_gdf['SAL_CODE_2021'] = SAL_gdf['SAL_CODE_2021'].astype(str)
# Out:
# /var/folders/dy/529c1fmn5nv__cgj0j36sm1m0000gn/T/ipykernel_89544/4268838904.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_suburbs_df['SAL_CODE_2021'] = all_suburbs_df['SAL_CODE_2021'].astype(str)

# %%
# Merge all_suburbs_df with relevant columns from SAL_gdf based on the 'SAL Suburb code' column
all_suburbs_df = all_suburbs_df.merge(SAL_gdf[['SAL_CODE_2021','AREASQKM21', 'geometry', 'station_count_in_suburb']], \
    on='SAL_CODE_2021', how='left')
all_suburbs_df[all_suburbs_df["station_count_in_suburb"].isnull()]
# Out:
#               Suburb Cluster  SAL suburb SAL_CODE_2021 Suburb Group  \
# 188  Outer Western Melbourne  Fieldstone            -1     Sydenham
#
#      AREASQKM21 geometry  station_count_in_suburb
# 188         NaN     None                      NaN

# %%
# drop Fieldstone has it has no SAL code therefore must be removed due to lack ABS data
all_suburbs_df = all_suburbs_df.drop(188)
all_suburbs_df
# Out:
#              Suburb Cluster     SAL suburb SAL_CODE_2021  \
# 0           Inner Melbourne    Albert Park         20018
# 1           Inner Melbourne    Middle Park         21677
# 2           Inner Melbourne  St Kilda West         22345
# 3           Inner Melbourne       Armadale         20066
# 4           Inner Melbourne  Carlton North         20496
# ..                      ...            ...           ...
# 564  Other Regional Centres      Traralgon         22569
# 565  Other Regional Centres     Wangaratta         22680
# 566  Other Regional Centres       Warragul         22698
# 567  Other Regional Centres    Warrnambool         22710
# 568  Other Regional Centres        Wodonga         22819
#
#                               Suburb Group  AREASQKM21  \
# 0    Albert Park-Middle Park-West St Kilda      2.8392
# 1    Albert Park-Middle Park-West St Kilda      0.8475
# 2    Albert Park-Middle Park-West St Kilda      0.5290
# 3                                 Armadale      2.1430
# 4                            Carlton North      1.8709
# ..                                     ...         ...
# 564                              Traralgon     56.2821
# 565                            Wanagaratta     48.7989
# 566                               Warragul     55.3164
# 567                            Warrnambool     65.5160
# 568                                Wodonga     37.4663
#
#                                               geometry  \
# 0    POLYGON ((144.95445 -37.83794, 144.95691 -37.8...
# 1    POLYGON ((144.96135 -37.84558, 144.96136 -37.8...
# 2    POLYGON ((144.97018 -37.85372, 144.97066 -37.8...
# 3    POLYGON ((145.02485 -37.85093, 145.02545 -37.8...
# 4    POLYGON ((144.97259 -37.79270, 144.97135 -37.7...
# ..                                                 ...
# 564  POLYGON ((146.56107 -38.18789, 146.56057 -38.1...
# 565  POLYGON ((146.31017 -36.38756, 146.31014 -36.3...
# 566  POLYGON ((145.94460 -38.12758, 145.94458 -38.1...
# 567  POLYGON ((142.46039 -38.33168, 142.47873 -38.3...
# 568  POLYGON ((146.88761 -36.15475, 146.88741 -36.1...
#
#      station_count_in_suburb
# 0                        0.0
# 1                        0.0
# 2                        0.0
# 3                        2.0
# 4                        0.0
# ..                       ...
# 564                      1.0
# 565                      1.0
# 566                      1.0
# 567                      2.0
# 568                      1.0
#
# [568 rows x 7 columns]

# %%
all_suburbs_df = all_suburbs_df.reset_index()
all_suburbs_df
# Out:
#      index          Suburb Cluster     SAL suburb SAL_CODE_2021  \
# 0        0         Inner Melbourne    Albert Park         20018
# 1        1         Inner Melbourne    Middle Park         21677
# 2        2         Inner Melbourne  St Kilda West         22345
# 3        3         Inner Melbourne       Armadale         20066
# 4        4         Inner Melbourne  Carlton North         20496
# ..     ...                     ...            ...           ...
# 563    564  Other Regional Centres      Traralgon         22569
# 564    565  Other Regional Centres     Wangaratta         22680
# 565    566  Other Regional Centres       Warragul         22698
# 566    567  Other Regional Centres    Warrnambool         22710
# 567    568  Other Regional Centres        Wodonga         22819
#
#                               Suburb Group  AREASQKM21  \
# 0    Albert Park-Middle Park-West St Kilda      2.8392
# 1    Albert Park-Middle Park-West St Kilda      0.8475
# 2    Albert Park-Middle Park-West St Kilda      0.5290
# 3                                 Armadale      2.1430
# 4                            Carlton North      1.8709
# ..                                     ...         ...
# 563                              Traralgon     56.2821
# 564                            Wanagaratta     48.7989
# 565                               Warragul     55.3164
# 566                            Warrnambool     65.5160
# 567                                Wodonga     37.4663
#
#                                               geometry  \
# 0    POLYGON ((144.95445 -37.83794, 144.95691 -37.8...
# 1    POLYGON ((144.96135 -37.84558, 144.96136 -37.8...
# 2    POLYGON ((144.97018 -37.85372, 144.97066 -37.8...
# 3    POLYGON ((145.02485 -37.85093, 145.02545 -37.8...
# 4    POLYGON ((144.97259 -37.79270, 144.97135 -37.7...
# ..                                                 ...
# 563  POLYGON ((146.56107 -38.18789, 146.56057 -38.1...
# 564  POLYGON ((146.31017 -36.38756, 146.31014 -36.3...
# 565  POLYGON ((145.94460 -38.12758, 145.94458 -38.1...
# 566  POLYGON ((142.46039 -38.33168, 142.47873 -38.3...
# 567  POLYGON ((146.88761 -36.15475, 146.88741 -36.1...
#
#      station_count_in_suburb
# 0                        0.0
# 1                        0.0
# 2                        0.0
# 3                        2.0
# 4                        0.0
# ..                       ...
# 563                      1.0
# 564                      1.0
# 565                      1.0
# 566                      2.0
# 567                      1.0
#
# [568 rows x 8 columns]

# %%
all_suburbs_df = all_suburbs_df.drop(columns="index")

# %% [markdown]
# #### 2.3 Two Closest Stations
# In this section the two nearest stations.  This is done through calculating the euclidean distance of the two closest stations to the centre of the suburb. The distances and station names are records in the dataset.

# %%
all_suburbs_gdf = gpd.GeoDataFrame(all_suburbs_df)
all_suburbs_gdf
# Out:
#              Suburb Cluster     SAL suburb SAL_CODE_2021  \
# 0           Inner Melbourne    Albert Park         20018
# 1           Inner Melbourne    Middle Park         21677
# 2           Inner Melbourne  St Kilda West         22345
# 3           Inner Melbourne       Armadale         20066
# 4           Inner Melbourne  Carlton North         20496
# ..                      ...            ...           ...
# 563  Other Regional Centres      Traralgon         22569
# 564  Other Regional Centres     Wangaratta         22680
# 565  Other Regional Centres       Warragul         22698
# 566  Other Regional Centres    Warrnambool         22710
# 567  Other Regional Centres        Wodonga         22819
#
#                               Suburb Group  AREASQKM21  \
# 0    Albert Park-Middle Park-West St Kilda      2.8392
# 1    Albert Park-Middle Park-West St Kilda      0.8475
# 2    Albert Park-Middle Park-West St Kilda      0.5290
# 3                                 Armadale      2.1430
# 4                            Carlton North      1.8709
# ..                                     ...         ...
# 563                              Traralgon     56.2821
# 564                            Wanagaratta     48.7989
# 565                               Warragul     55.3164
# 566                            Warrnambool     65.5160
# 567                                Wodonga     37.4663
#
#                                               geometry  \
# 0    POLYGON ((144.95445 -37.83794, 144.95691 -37.8...
# 1    POLYGON ((144.96135 -37.84558, 144.96136 -37.8...
# 2    POLYGON ((144.97018 -37.85372, 144.97066 -37.8...
# 3    POLYGON ((145.02485 -37.85093, 145.02545 -37.8...
# 4    POLYGON ((144.97259 -37.79270, 144.97135 -37.7...
# ..                                                 ...
# 563  POLYGON ((146.56107 -38.18789, 146.56057 -38.1...
# 564  POLYGON ((146.31017 -36.38756, 146.31014 -36.3...
# 565  POLYGON ((145.94460 -38.12758, 145.94458 -38.1...
# 566  POLYGON ((142.46039 -38.33168, 142.47873 -38.3...
# 567  POLYGON ((146.88761 -36.15475, 146.88741 -36.1...
#
#      station_count_in_suburb
# 0                        0.0
# 1                        0.0
# 2                        0.0
# 3                        2.0
# 4                        0.0
# ..                       ...
# 563                      1.0
# 564                      1.0
# 565                      1.0
# 566                      2.0
# 567                      1.0
#
# [568 rows x 7 columns]

# %%
all_suburbs_gdf['suburb_centroid'] = all_suburbs_gdf['geometry'].centroid
all_suburbs_gdf
# Out:
# /var/folders/dy/529c1fmn5nv__cgj0j36sm1m0000gn/T/ipykernel_89544/3793238674.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   all_suburbs_gdf['suburb_centroid'] = all_suburbs_gdf['geometry'].centroid
#              Suburb Cluster     SAL suburb SAL_CODE_2021  \
# 0           Inner Melbourne    Albert Park         20018
# 1           Inner Melbourne    Middle Park         21677
# 2           Inner Melbourne  St Kilda West         22345
# 3           Inner Melbourne       Armadale         20066
# 4           Inner Melbourne  Carlton North         20496
# ..                      ...            ...           ...
# 563  Other Regional Centres      Traralgon         22569
# 564  Other Regional Centres     Wangaratta         22680
# 565  Other Regional Centres       Warragul         22698
# 566  Other Regional Centres    Warrnambool         22710
# 567  Other Regional Centres        Wodonga         22819
#
#                               Suburb Group  AREASQKM21  \
# 0    Albert Park-Middle Park-West St Kilda      2.8392
# 1    Albert Park-Middle Park-West St Kilda      0.8475
# 2    Albert Park-Middle Park-West St Kilda      0.5290
# 3                                 Armadale      2.1430
# 4                            Carlton North      1.8709
# ..                                     ...         ...
# 563                              Traralgon     56.2821
# 564                            Wanagaratta     48.7989
# 565                               Warragul     55.3164
# 566                            Warrnambool     65.5160
# 567                                Wodonga     37.4663
#
#                                               geometry  \
# 0    POLYGON ((144.95445 -37.83794, 144.95691 -37.8...
# 1    POLYGON ((144.96135 -37.84558, 144.96136 -37.8...
# 2    POLYGON ((144.97018 -37.85372, 144.97066 -37.8...
# 3    POLYGON ((145.02485 -37.85093, 145.02545 -37.8...
# 4    POLYGON ((144.97259 -37.79270, 144.97135 -37.7...
# ..                                                 ...
# 563  POLYGON ((146.56107 -38.18789, 146.56057 -38.1...
# 564  POLYGON ((146.31017 -36.38756, 146.31014 -36.3...
# 565  POLYGON ((145.94460 -38.12758, 145.94458 -38.1...
# 566  POLYGON ((142.46039 -38.33168, 142.47873 -38.3...
# 567  POLYGON ((146.88761 -36.15475, 146.88741 -36.1...
#
#      station_count_in_suburb              suburb_centroid
# 0                        0.0  POINT (144.96105 -37.84518)
# 1                        0.0  POINT (144.96202 -37.85115)
# 2                        0.0  POINT (144.97125 -37.85796)
# 3                        2.0  POINT (145.02023 -37.85666)
# 4                        0.0  POINT (144.96849 -37.78659)
# ..                       ...                          ...
# 563                      1.0  POINT (146.51978 -38.20334)
# 564                      1.0  POINT (146.31601 -36.36938)
# 565                      1.0  POINT (145.92997 -38.15372)
# 566                      2.0  POINT (142.49818 -38.36886)
# 567                      1.0  POINT (146.88181 -36.12306)
#
# [568 rows x 8 columns]

# %%
def euclidean_distance(lat1, lon1, lat2, lon2):
    """ calculate eulcidean distance between two longitude/latitude coordinates """
    return np.sqrt((lat2 - lat1) ** 2 + (lon2 - lon1) ** 2)

def find_closest_stations(row, train_stations, num_stations=2):
    """ Compute distances from the current row to all train stations using Euclidean distance """
    distances = train_stations.apply(
        lambda x: euclidean_distance(row['suburb_centroid'].y, row['suburb_centroid'].x, x['LATITUDE'], x['LONGITUDE']),
        axis=1
    )
    
    # Get the indices of the closest stations
    closest_indices = distances.nsmallest(num_stations).index
    closest_stations = train_stations.loc[closest_indices]
    
    # Return a list of stop names and coordinates
    return closest_stations[['STOP_NAME', 'LATITUDE', 'LONGITUDE']].to_dict(orient='records')

# Apply the function to each row in historical_rent_df
all_suburbs_gdf['closest_stations'] = all_suburbs_gdf.apply(
    lambda row: find_closest_stations(row, trains_gdf), axis=1
)
all_suburbs_gdf
# Out:
#              Suburb Cluster     SAL suburb SAL_CODE_2021  \
# 0           Inner Melbourne    Albert Park         20018
# 1           Inner Melbourne    Middle Park         21677
# 2           Inner Melbourne  St Kilda West         22345
# 3           Inner Melbourne       Armadale         20066
# 4           Inner Melbourne  Carlton North         20496
# ..                      ...            ...           ...
# 563  Other Regional Centres      Traralgon         22569
# 564  Other Regional Centres     Wangaratta         22680
# 565  Other Regional Centres       Warragul         22698
# 566  Other Regional Centres    Warrnambool         22710
# 567  Other Regional Centres        Wodonga         22819
#
#                               Suburb Group  AREASQKM21  \
# 0    Albert Park-Middle Park-West St Kilda      2.8392
# 1    Albert Park-Middle Park-West St Kilda      0.8475
# 2    Albert Park-Middle Park-West St Kilda      0.5290
# 3                                 Armadale      2.1430
# 4                            Carlton North      1.8709
# ..                                     ...         ...
# 563                              Traralgon     56.2821
# 564                            Wanagaratta     48.7989
# 565                               Warragul     55.3164
# 566                            Warrnambool     65.5160
# 567                                Wodonga     37.4663
#
#                                               geometry  \
# 0    POLYGON ((144.95445 -37.83794, 144.95691 -37.8...
# 1    POLYGON ((144.96135 -37.84558, 144.96136 -37.8...
# 2    POLYGON ((144.97018 -37.85372, 144.97066 -37.8...
# 3    POLYGON ((145.02485 -37.85093, 145.02545 -37.8...
# 4    POLYGON ((144.97259 -37.79270, 144.97135 -37.7...
# ..                                                 ...
# 563  POLYGON ((146.56107 -38.18789, 146.56057 -38.1...
# 564  POLYGON ((146.31017 -36.38756, 146.31014 -36.3...
# 565  POLYGON ((145.94460 -38.12758, 145.94458 -38.1...
# 566  POLYGON ((142.46039 -38.33168, 142.47873 -38.3...
# 567  POLYGON ((146.88761 -36.15475, 146.88741 -36.1...
#
#      station_count_in_suburb              suburb_centroid  \
# 0                        0.0  POINT (144.96105 -37.84518)
# 1                        0.0  POINT (144.96202 -37.85115)
# 2                        0.0  POINT (144.97125 -37.85796)
# 3                        2.0  POINT (145.02023 -37.85666)
# 4                        0.0  POINT (144.96849 -37.78659)
# ..                       ...                          ...
# 563                      1.0  POINT (146.51978 -38.20334)
# 564                      1.0  POINT (146.31601 -36.36938)
# 565                      1.0  POINT (145.92997 -38.15372)
# 566                      2.0  POINT (142.49818 -38.36886)
# 567                      1.0  POINT (146.88181 -36.12306)
#
#                                       closest_stations
# 0    [{'STOP_NAME': 'Flinders Street', 'LATITUDE': ...
# 1    [{'STOP_NAME': 'Prahran', 'LATITUDE': -37.8495...
# 2    [{'STOP_NAME': 'Prahran', 'LATITUDE': -37.8495...
# 3    [{'STOP_NAME': 'Armadale', 'LATITUDE': -37.856...
# 4    [{'STOP_NAME': 'Jewell', 'LATITUDE': -37.77498...
# ..                                                 ...
# 563  [{'STOP_NAME': 'Traralgon', 'LATITUDE': -38.19...
# 564  [{'STOP_NAME': 'Wangaratta', 'LATITUDE': -36.3...
# 565  [{'STOP_NAME': 'Warragul', 'LATITUDE': -38.165...
# 566  [{'STOP_NAME': 'Warrnambool', 'LATITUDE': -38....
# 567  [{'STOP_NAME': 'Wodonga', 'LATITUDE': -36.1058...
#
# [568 rows x 9 columns]

# %%
# Create separate columns for each closest station
def expand_closest_stations(row):
    """ Flatten the list of closest stations into individual columns """
    result = {}
    for i, station in enumerate(row['closest_stations']):
        for key in ['STOP_NAME', 'LATITUDE', 'LONGITUDE']:
            result[f'closest_station_{i+1}_{key}'] = station[key]
    return result

# Apply and merge the expanded closest stations data
expanded_stations = all_suburbs_gdf.apply(expand_closest_stations, axis=1)
expanded_stations_df = pd.DataFrame(expanded_stations.tolist())
# Concatenate the original DataFrame with the new columns
all_suburbs_gdf = pd.concat([all_suburbs_gdf, expanded_stations_df], axis=1)
all_suburbs_gdf
# Out:
#              Suburb Cluster     SAL suburb SAL_CODE_2021  \
# 0           Inner Melbourne    Albert Park         20018
# 1           Inner Melbourne    Middle Park         21677
# 2           Inner Melbourne  St Kilda West         22345
# 3           Inner Melbourne       Armadale         20066
# 4           Inner Melbourne  Carlton North         20496
# ..                      ...            ...           ...
# 563  Other Regional Centres      Traralgon         22569
# 564  Other Regional Centres     Wangaratta         22680
# 565  Other Regional Centres       Warragul         22698
# 566  Other Regional Centres    Warrnambool         22710
# 567  Other Regional Centres        Wodonga         22819
#
#                               Suburb Group  AREASQKM21  \
# 0    Albert Park-Middle Park-West St Kilda      2.8392
# 1    Albert Park-Middle Park-West St Kilda      0.8475
# 2    Albert Park-Middle Park-West St Kilda      0.5290
# 3                                 Armadale      2.1430
# 4                            Carlton North      1.8709
# ..                                     ...         ...
# 563                              Traralgon     56.2821
# 564                            Wanagaratta     48.7989
# 565                               Warragul     55.3164
# 566                            Warrnambool     65.5160
# 567                                Wodonga     37.4663
#
#                                               geometry  \
# 0    POLYGON ((144.95445 -37.83794, 144.95691 -37.8...
# 1    POLYGON ((144.96135 -37.84558, 144.96136 -37.8...
# 2    POLYGON ((144.97018 -37.85372, 144.97066 -37.8...
# 3    POLYGON ((145.02485 -37.85093, 145.02545 -37.8...
# 4    POLYGON ((144.97259 -37.79270, 144.97135 -37.7...
# ..                                                 ...
# 563  POLYGON ((146.56107 -38.18789, 146.56057 -38.1...
# 564  POLYGON ((146.31017 -36.38756, 146.31014 -36.3...
# 565  POLYGON ((145.94460 -38.12758, 145.94458 -38.1...
# 566  POLYGON ((142.46039 -38.33168, 142.47873 -38.3...
# 567  POLYGON ((146.88761 -36.15475, 146.88741 -36.1...
#
#      station_count_in_suburb              suburb_centroid  \
# 0                        0.0  POINT (144.96105 -37.84518)
# 1                        0.0  POINT (144.96202 -37.85115)
# 2                        0.0  POINT (144.97125 -37.85796)
# 3                        2.0  POINT (145.02023 -37.85666)
# 4                        0.0  POINT (144.96849 -37.78659)
# ..                       ...                          ...
# 563                      1.0  POINT (146.51978 -38.20334)
# 564                      1.0  POINT (146.31601 -36.36938)
# 565                      1.0  POINT (145.92997 -38.15372)
# 566                      2.0  POINT (142.49818 -38.36886)
# 567                      1.0  POINT (146.88181 -36.12306)
#
#                                       closest_stations  \
# 0    [{'STOP_NAME': 'Flinders Street', 'LATITUDE': ...
# 1    [{'STOP_NAME': 'Prahran', 'LATITUDE': -37.8495...
# 2    [{'STOP_NAME': 'Prahran', 'LATITUDE': -37.8495...
# 3    [{'STOP_NAME': 'Armadale', 'LATITUDE': -37.856...
# 4    [{'STOP_NAME': 'Jewell', 'LATITUDE': -37.77498...
# ..                                                 ...
# 563  [{'STOP_NAME': 'Traralgon', 'LATITUDE': -38.19...
# 564  [{'STOP_NAME': 'Wangaratta', 'LATITUDE': -36.3...
# 565  [{'STOP_NAME': 'Warragul', 'LATITUDE': -38.165...
# 566  [{'STOP_NAME': 'Warrnambool', 'LATITUDE': -38....
# 567  [{'STOP_NAME': 'Wodonga', 'LATITUDE': -36.1058...
#
#     closest_station_1_STOP_NAME  closest_station_1_LATITUDE  \
# 0               Flinders Street                  -37.818305
# 1                       Prahran                  -37.849518
# 2                       Prahran                  -37.849518
# 3                      Armadale                  -37.856452
# 4                        Jewell                  -37.774987
# ..                          ...                         ...
# 563                   Traralgon                  -38.198885
# 564                  Wangaratta                  -36.355101
# 565                    Warragul                  -38.165229
# 566                 Warrnambool                  -38.385014
# 567                     Wodonga                  -36.105827
#
#      closest_station_1_LONGITUDE closest_station_2_STOP_NAME  \
# 0                     144.966964              Southern Cross
# 1                     144.989860                     Windsor
# 2                     144.989860                     Windsor
# 3                     145.019326                      Toorak
# 4                     144.958717                  Royal Park
# ..                           ...                         ...
# 563                   146.537882                     Morwell
# 564                   146.317038                 Springhurst
# 565                   145.932674                      Drouin
# 566                   142.475545                 Warrnambool
# 567                   146.871266                    Chiltern
#
#      closest_station_2_LATITUDE  closest_station_2_LONGITUDE
# 0                    -37.817936                   144.951411
# 1                    -37.856053                   144.992035
# 2                    -37.856053                   144.992035
# 3                    -37.850774                   145.013909
# 4                    -37.781193                   144.952301
# ..                          ...                          ...
# 563                  -38.236719                   146.396753
# 564                  -36.185893                   146.470417
# 565                  -38.136452                   145.855947
# 566                  -38.386392                   142.538871
# 567                  -36.155637                   146.611375
#
# [568 rows x 15 columns]

# %%
#output the data
all_suburbs_gdf.to_csv("../../data/curated/station_data_aggregated.csv")
