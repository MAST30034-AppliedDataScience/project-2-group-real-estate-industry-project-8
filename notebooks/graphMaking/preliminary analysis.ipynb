# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/curated/Processed Data Final.csv')

# %%
pd.set_option('display.max_columns', None)
# df.drop(columns = ['2024_average_baths', '2024_average_parking', 
#                    '2024_property_count'], axis=1, inplace=True)
# df

# %%
df
# Out:
#       distance_to_CBD  time_to_CBD  distance_to_station  time_to_station  \
# 0           11.733250     8.640331             8.364811         6.249589
# 1           10.983561     8.322540             9.375177         6.892845
# 2           11.001156     8.255751             9.516059         6.626585
# 3           10.486549     7.682160             8.054364         5.964350
# 4           10.433872     7.682482             8.539600         6.585206
# ...               ...          ...                  ...              ...
# 6092        10.812341     8.159432             9.480612         7.060648
# 6093        10.755069     7.927829             8.886603         6.591399
# 6094        10.004165     7.311018             8.276318         6.120737
# 6095        10.528393     7.918847             7.256086         5.047931
# 6096        10.649891     7.858138             8.593932         6.363545
#
#       year  Average_household_size  Average_num_psns_per_bedroom  \
# ...

# %%
dfFiltered = df[df['year'] <= 2024]

# %%
dfFiltered
# Out:
#       distance_to_CBD  time_to_CBD  distance_to_station  time_to_station  \
# 0           11.733250     8.640331             8.364811         6.249589
# 1           10.983561     8.322540             9.375177         6.892845
# 2           11.001156     8.255751             9.516059         6.626585
# 3           10.486549     7.682160             8.054364         5.964350
# 4           10.433872     7.682482             8.539600         6.585206
# ...               ...          ...                  ...              ...
# 4216         8.688268     6.547072             7.591408         5.727824
# 4217         7.654443     5.678465             7.328766         5.542831
# 4218        11.019448     8.179732             9.225721         6.806055
# 4219        10.951168     8.099311             9.301770         6.983697
# 4220        10.175882     7.631335             7.903116         5.924790
#
#       year  Average_household_size  Average_num_psns_per_bedroom  \
# ...

# %%
dfFilteredV2 =  dfFiltered

# %%
dfFilteredV2
# Out:
#       distance_to_CBD  time_to_CBD  distance_to_station  time_to_station  \
# 0           11.733250     8.640331             8.364811         6.249589
# 1           10.983561     8.322540             9.375177         6.892845
# 2           11.001156     8.255751             9.516059         6.626585
# 3           10.486549     7.682160             8.054364         5.964350
# 4           10.433872     7.682482             8.539600         6.585206
# ...               ...          ...                  ...              ...
# 4216         8.688268     6.547072             7.591408         5.727824
# 4217         7.654443     5.678465             7.328766         5.542831
# 4218        11.019448     8.179732             9.225721         6.806055
# 4219        10.951168     8.099311             9.301770         6.983697
# 4220        10.175882     7.631335             7.903116         5.924790
#
#       year  Average_household_size  Average_num_psns_per_bedroom  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr_matrix = dfFilteredV2.corr()

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Create a heatmap using seaborn
sns.heatmap(corr_matrix, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Show the plot
plt.title('Correlation Matrix for dfFilteredV2')
plt.show()

# %%
# Create a scatter plot to visualize the relationship between distance_to_CBD and average_weekly_rent/inflation/household_size
plt.figure(figsize=(10, 6))
sns.scatterplot(x='distance_to_CBD', y='average_weekly_rent/inflation/household_size', data=dfFilteredV2)

# Add labels and title
plt.xlabel('Distance to CBD')
plt.ylabel('Adjusted Average Weekly Rent')
plt.title('Distance to CBD vs. Adjusted Average Weekly Rent')

# Show the plot
plt.show()

# %%
df_2022 = dfFilteredV2[dfFilteredV2['year'] == 2022]
plt.figure(figsize=(10, 10))
# Scatter plot for 2022
plt.subplot(2, 1, 1)
sns.scatterplot(x='distance_to_CBD', y='average_weekly_rent/inflation/household_size', data=df_2022)
plt.title('2022: Distance to CBD vs. Adjusted Average Weekly Rent')
plt.xlabel('Distance to CBD')
plt.ylabel('Adjusted Average Weekly Rent')
plt.show()

# %%
df_2023 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Create a figure for the plots
plt.figure(figsize=(10, 10))


# Scatter plot for 2023
plt.subplot(2, 1, 2)
sns.scatterplot(x='distance_to_CBD', y='average_weekly_rent/inflation/household_size', data=df_2023)
plt.title('2023: Distance to CBD vs. Adjusted Average Weekly Rent')
plt.xlabel('Distance to CBD')
plt.ylabel('Adjusted Average Weekly Rent')

# Show the plots
plt.savefig('../../plots/distanceCBD2023VSRent.png', bbox_inches='tight')
plt.show()

# %%
df_2022_filtered = dfFilteredV2[(dfFilteredV2['year'] == 2023)]

# Create a scatter plot of 'A Crimes against the person/per_person' vs 'average_weekly_rent/inflation/household_size' for 2022
plt.figure(figsize=(10, 10))
sns.scatterplot(x='A Crimes against the person/per_person', 
                y='average_weekly_rent/inflation/household_size', 
                data=df_2022_filtered)

# Add labels and title
plt.xlabel('A Crimes against the person/per_person')
plt.ylabel('Adjusted Average Weekly Rent')
plt.title('2023: A Crimes against the person/per_person vs. Adjusted Average Weekly Rent')

# Save the plot
plt.savefig('../../plots/avgWeeklyRentVSCrimesAgainstPerson.png', bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Filter for the year 2022
df_2022_filtered = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Reverse the log transformation to get the actual Tot_P_P
df_2022_filtered['Actual_Tot_P_P'] = np.exp(df_2022_filtered['Tot_P_P'])

# Calculate total crimes against the person by multiplying crimes per person by the actual Tot_P_P
df_2022_filtered['Total Crimes against the person'] = df_2022_filtered['A Crimes against the person/per_person'] * df_2022_filtered['Actual_Tot_P_P']

# Create a scatter plot of 'Total Crimes against the person' vs 'average_weekly_rent/inflation/household_size' for 2022
plt.figure(figsize=(10, 10))
sns.scatterplot(x='Total Crimes against the person', 
                y='average_weekly_rent/inflation/household_size', 
                data=df_2022_filtered)

# Add labels and title
plt.xlabel('Total Crimes against the person')
plt.ylabel('Adjusted Average Weekly Rent')
plt.title('2023: Total Crimes against the person vs. Adjusted Average Weekly Rent')

# Save the plot
plt.savefig('../../plots/totalCrimesAgainstPersonVSAdjustedRent_ActualPopulation.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1185/1735060974.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022_filtered['Actual_Tot_P_P'] = np.exp(df_2022_filtered['Tot_P_P'])
# /tmp/ipykernel_1185/1735060974.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022_filtered['Total Crimes against the person'] = df_2022_filtered['A Crimes against the person/per_person'] * df_2022_filtered['Actual_Tot_P_P']

# %%
correlation = df_2022['A Crimes against the person/per_person'].corr(df_2022['average_weekly_rent/inflation/household_size'])
correlation
# Out:
# np.float64(0.07542437280597014)

# %%
df_2022 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Create a scatter plot of 'A Crimes against the person/per_person' vs 'average_weekly_rent/inflation/household_size' for 2022
plt.figure(figsize=(10, 10))
sns.scatterplot(x='C Drug offences/per_person', y='average_weekly_rent/inflation/household_size', data=df_2022)

# Add labels and title
plt.xlabel('Drug offences')
plt.ylabel('Adjusted Average Weekly Rent')
plt.title('2023: Drug Offences vs. Adjusted Average Weekly Rent')

plt.savefig('../../plots/avgWeeklyRentVSDrugCrimes.png', bbox_inches='tight')
# Show the plot
plt.show()

# %%
# Filter for the year 2022
df_2022 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Reverse the log transformation to get the actual Tot_P_P
df_2022['Actual_Tot_P_P'] = np.exp(df_2022['Tot_P_P'])

# Calculate total drug offences by multiplying drug offences per person by the actual Tot_P_P
df_2022['Total Drug Offences'] = df_2022['C Drug offences/per_person'] * df_2022['Actual_Tot_P_P']

# Create a scatter plot of 'Total Drug Offences' vs 'average_weekly_rent/inflation/household_size' for 2022
plt.figure(figsize=(10, 10))
sns.scatterplot(x='Total Drug Offences', 
                y='average_weekly_rent/inflation/household_size', 
                data=df_2022)

# Add labels and title
plt.xlabel('Total Drug Offences')
plt.ylabel('Adjusted Average Weekly Rent')
plt.title('2023: Total Drug Offences vs. Adjusted Average Weekly Rent')

# Save the plot
plt.savefig('../../plots/avgWeeklyRentVSTotalDrugCrimes.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1185/2621556890.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['Actual_Tot_P_P'] = np.exp(df_2022['Tot_P_P'])
# /tmp/ipykernel_1185/2621556890.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['Total Drug Offences'] = df_2022['C Drug offences/per_person'] * df_2022['Actual_Tot_P_P']

# %%
df_2023 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Sum the crime-related columns
df_2023['Total Crimes'] = (df_2023['A Crimes against the person/per_person'] +
                           df_2023['B Property and deception offences/per_person'] +
                           df_2023['C Drug offences/per_person'] +
                           df_2023['D Public order and security offences/per_person'] +
                           df_2023['E Justice procedures offences/per_person'] +
                           df_2023['F Other offences/per_person'])

# Create a scatter plot of Total Crimes vs Adjusted Average Weekly Rent
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Total Crimes', y='average_weekly_rent/inflation/household_size', data=df_2023)

# Add labels and title
plt.xlabel('Total Crimes (Sum of All Offences)')
plt.ylabel('Adjusted Average Weekly Rent')
plt.title('2023: Total Crimes vs. Adjusted Average Weekly Rent')

plt.savefig('../../plots/totalCrimeVsAvgWeeklyRent.png', bbox_inches='tight')
# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1185/1088530227.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['Total Crimes'] = (df_2023['A Crimes against the person/per_person'] +

# %%
import geopandas as gpd

# %%
# import SAL
sal_code = gpd.read_file("../../data/landing/SAL_data/SAL_2021_AUST_GDA2020.shp")

# Drop non-integer SAL_CODE21 values
gdf = sal_code[sal_code['SAL_CODE21'].apply(lambda x: str(x).isdigit())]
gdf["SAL_CODE21"] = gdf["SAL_CODE21"].astype(int)
# Out:
# /home/joshuali/.local/lib/python3.10/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
dfGeom = df.merge(gdf, right_on='SAL_CODE21', left_on='SAL_CODE')

# %%
from math import radians, cos, sin, asin, sqrt

# for better visualisaiton, remove suburbs too far outside melbourne
# Compute distance to Melbourne CBD
melbourne_cbd_coords = (-37.8136, 144.9631)  # Latitude and Longitude of Melbourne CBD

# Function to calculate distance
def haversine(lat1, lon1, lat2, lon2):
    # convert decimal degrees to radians
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    # haversine formula
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371  # Radius of earth in kilometers
    return c * r

# Apply the function to calculate distance to Melbourne CBD
dfGeom['distance_to_CBD'] = dfGeom.apply(lambda row: haversine(row['geometry'].centroid.y, row['geometry'].centroid.x, melbourne_cbd_coords[0], melbourne_cbd_coords[1]), axis=1)

# Filter out suburbs too far outside Melbourne (e.g., more than 50 km)
dfGeom = dfGeom[dfGeom['distance_to_CBD'] <= 100]

# %%
# Filter for the year 2022
df_2022 = dfGeom[dfGeom['year'] == 2023]

# Ensure the GeoDataFrame has a geometry column for plotting
if 'geometry' in df_2022.columns:
    df_2022 = gpd.GeoDataFrame(df_2022, geometry='geometry')

# Plot the data as a choropleth map
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# Plot the GeoDataFrame, coloring by 'A Crimes against the person/per_person' column
df_2022.plot(
    column='A Crimes against the person/per_person',  # Data column for coloring
    cmap='YlOrRd',  # Color map
    linewidth=0.8,  # Line width between polygons
    ax=ax,          # Axis to plot on
    edgecolor='0.8', # Edge color
    legend=True     # Add a legend
)

# Add a title
ax.set_title('A Crimes against the person/per_person - 2023', fontsize=15)

plt.savefig('../../plots/crimesAgainstPerson2023Map.png', bbox_inches='tight')
# Show the plot
plt.show()

# %%
# Filter the DataFrame for the year 2022
df_2022 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Create the scatter plot using Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_2022, x='proximity_to_beach', y='average_weekly_rent/inflation/household_size', alpha=0.6)

# Add labels and title
plt.xlabel('Proximity to Beach', fontsize=14)
plt.ylabel('Adjusted Average Weekly Rent', fontsize=14)
plt.title('Proximity to Beach vs Adjusted Average Weekly Rent (2023)', fontsize=16)

# Show grid
plt.grid(True)

plt.savefig('../../plots/proximityToBeachVsAvgWeeklyRent.png', bbox_inches='tight')
# Show the plot
plt.show()

# %%
dfFilteredV2
# Out:
#       distance_to_CBD  time_to_CBD  distance_to_station  time_to_station  \
# 0           11.733250     8.640331             8.364811         6.249589
# 1           10.983561     8.322540             9.375177         6.892845
# 2           11.001156     8.255751             9.516059         6.626585
# 3           10.486549     7.682160             8.054364         5.964350
# 4           10.433872     7.682482             8.539600         6.585206
# ...               ...          ...                  ...              ...
# 4216         8.688268     6.547072             7.591408         5.727824
# 4217         7.654443     5.678465             7.328766         5.542831
# 4218        11.019448     8.179732             9.225721         6.806055
# 4219        10.951168     8.099311             9.301770         6.983697
# 4220        10.175882     7.631335             7.903116         5.924790
#
#       year  Average_household_size  Average_num_psns_per_bedroom  \
# ...

# %%
# Filter the DataFrame for the year 2023 and exclude specific median_score values
df_2023 = dfFilteredV2[(dfFilteredV2['year'] == 2023) & 
                        (~dfFilteredV2['median_score'].isin([3.3921110213564774, 3.401242284864897]))]

# Create the scatter plot using Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_2023, x='median_score', y='average_weekly_rent/inflation/household_size', alpha=0.6)

# Add labels and title
plt.xlabel('Median VCE Study Score (log)', fontsize=14)
plt.ylabel('Adjusted Average Weekly Rent', fontsize=14)
plt.title('Median VCE Study Score (log) vs Adjusted Average Weekly Rent (2023)', fontsize=16)

# Show grid
plt.grid(True)

plt.savefig('../../plots/studyScoreVsAvgWeeklyRent.png', bbox_inches='tight')
# Show the plot
plt.show()

# %%
# Filter the DataFrame for the year 2023 and exclude average_weekly_rent/inflation/household_size > 50000
df_2023 = dfFilteredV2[(dfFilteredV2['year'] == 2023) & 
                        (dfFilteredV2['distance_to_station'] <= 50000)]

# Create the scatter plot using Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_2023, x='distance_to_station', y='average_weekly_rent/inflation/household_size', alpha=0.6)

# Add labels and title
plt.xlabel('Distance to Station', fontsize=14)
plt.ylabel('Adjusted Average Weekly Rent', fontsize=14)
plt.title('Distance to Station vs Adjusted Average Weekly Rent (2023)', fontsize=16)

# Show grid
plt.grid(True)

# Show the plot
plt.show()

# %%
# Filter for the year 2023
df_2023 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Create the first plot for Median Family Income (Weekly) vs Adjusted Average Weekly Rent
plt.figure(figsize=(10, 10))
sns.scatterplot(x='Median_tot_fam_inc_weekly/inflation', 
                y='average_weekly_rent/inflation/household_size', 
                data=df_2023)

# Add labels and title
plt.xlabel('Median Family Income (Weekly) Adjusted for Inflation')
plt.ylabel('Adjusted Average Weekly Rent per Household Size')
plt.title('2023: Median Family Income (Weekly) vs Adjusted Average Weekly Rent')

# Save the first plot
plt.savefig('../../plots/medianFamilyIncome_vs_AvgWeeklyRent_2023.png', bbox_inches='tight')

# Show the first plot
plt.show()


# Create the second plot for Median Personal Income (Weekly) vs Adjusted Average Weekly Rent
plt.figure(figsize=(10, 10))
sns.scatterplot(x='Median_tot_prsnl_inc_weekly/inflation', 
                y='average_weekly_rent/inflation/household_size', 
                data=df_2023)

# Add labels and title
plt.xlabel('Median Personal Income (Weekly) Adjusted for Inflation')
plt.ylabel('Adjusted Average Weekly Rent per Household Size')
plt.title('2023: Median Personal Income (Weekly) vs Adjusted Average Weekly Rent')

# Save the second plot
plt.savefig('../../plots/medianPersonalIncome_vs_AvgWeeklyRent_2023.png', bbox_inches='tight')

# Show the second plot
plt.show()

# %%
dfFilteredV2
# Out:
#       distance_to_CBD  time_to_CBD  distance_to_station  time_to_station  \
# 0           11.733250     8.640331             8.364811         6.249589
# 1           10.983561     8.322540             9.375177         6.892845
# 2           11.001156     8.255751             9.516059         6.626585
# 3           10.486549     7.682160             8.054364         5.964350
# 4           10.433872     7.682482             8.539600         6.585206
# ...               ...          ...                  ...              ...
# 4216         8.688268     6.547072             7.591408         5.727824
# 4217         7.654443     5.678465             7.328766         5.542831
# 4218        11.019448     8.179732             9.225721         6.806055
# 4219        10.951168     8.099311             9.301770         6.983697
# 4220        10.175882     7.631335             7.903116         5.924790
#
#       year  Average_household_size  Average_num_psns_per_bedroom  \
# ...

# %%
# Filter for the year 2023
df_2023 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Create a scatter plot of 'Parks and gardens' vs 'average_weekly_rent/inflation/household_size' for 2023
plt.figure(figsize=(10, 10))
sns.scatterplot(x='recreation density', 
                y='average_weekly_rent/inflation/household_size', 
                data=df_2023)

# Add labels and title
plt.xlabel('Recreation Density')
plt.ylabel('Adjusted Average Weekly Rent per Household Size')
plt.title('2023: Recreation Density vs Adjusted Average Weekly Rent')

# Save the plot
plt.savefig('../../plots/recreationDensity_vs_AvgWeeklyRent_2023.png', bbox_inches='tight')

# Show the plot
plt.show()

# %%
suburbNames = pd.read_csv('../../data2/curated/notFINAL_COMPLETE_DATASET_no_poly.csv')

# %%
suburbNames
# Out:
#           Suburb Cluster SAL_suburb  SAL_CODE                 Suburb Group  \
# 0               Ballarat  Alfredton     20023          Wendouree-Alfredton
# 1               Ballarat  Alfredton     20023          Wendouree-Alfredton
# 2               Ballarat  Alfredton     20023          Wendouree-Alfredton
# 3               Ballarat  Alfredton     20023          Wendouree-Alfredton
# 4               Ballarat  Alfredton     20023          Wendouree-Alfredton
# ...                  ...        ...       ...                          ...
# 7353  Southern Melbourne  Waterways     22720  Mentone-Parkdale-Mordialloc
# 7354  Southern Melbourne  Waterways     22720  Mentone-Parkdale-Mordialloc
# 7355  Southern Melbourne  Waterways     22720  Mentone-Parkdale-Mordialloc
# 7356  Southern Melbourne  Waterways     22720  Mentone-Parkdale-Mordialloc
# 7357  Southern Melbourne  Waterways     22720  Mentone-Parkdale-Mordialloc
#
#       AREASQKM21  station_count_in_suburb  \
# ...

# %%
# Merge dfFilteredV2 with suburbName on the SAL_CODE column
dfFilteredV2 = dfFilteredV2.merge(suburbNames[['SAL_CODE', 'SAL_suburb', 'year']], 
                                  on=['SAL_CODE', 'year'], 
                                  how='left')

# Rename SAL_suburb to suburb_name in dfFilteredV2
dfFilteredV2.rename(columns={'SAL_suburb': 'suburb_name'}, inplace=True)

# %%
dfFilteredV2
# Out:
#       distance_to_CBD  time_to_CBD  distance_to_station  time_to_station  \
# 0           11.733250     8.640331             8.364811         6.249589
# 1           10.983561     8.322540             9.375177         6.892845
# 2           11.001156     8.255751             9.516059         6.626585
# 3           10.486549     7.682160             8.054364         5.964350
# 4           10.433872     7.682482             8.539600         6.585206
# ...               ...          ...                  ...              ...
# 4216         8.688268     6.547072             7.591408         5.727824
# 4217         7.654443     5.678465             7.328766         5.542831
# 4218        11.019448     8.179732             9.225721         6.806055
# 4219        10.951168     8.099311             9.301770         6.983697
# 4220        10.175882     7.631335             7.903116         5.924790
#
#       year  Average_household_size  Average_num_psns_per_bedroom  \
# ...

# %%
# Group by 'suburb_name' and sum the 'Parks and gardens'
top_suburbs = dfFilteredV2.groupby('suburb_name')['recreation density'].sum().reset_index()

# Sort the suburbs based on the 'Parks and gardens' values
top_suburbs = top_suburbs.sort_values(by='recreation density', ascending=False).head(20)

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='recreation density', y='suburb_name', data=top_suburbs, palette='viridis')

# Add labels and title
plt.xlabel('Recreation Density')
plt.ylabel('Suburbs')
plt.title('Top 20 Suburbs Based on Recreation Density')

# Show the plot
plt.tight_layout()
plt.savefig('../../plots/top20SuburbsRecreationDensity.png', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1185/2005081597.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='recreation density', y='suburb_name', data=top_suburbs, palette='viridis')

# %%
top_suburbs_income = dfFilteredV2.groupby('suburb_name')['Median_tot_fam_inc_weekly/inflation'].sum().reset_index()

# Sort the suburbs based on the 'Median_tot_fam_inc_weekly/inflation' values
top_suburbs_income = top_suburbs_income.sort_values(by='Median_tot_fam_inc_weekly/inflation', ascending=False).head(20)

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Median_tot_fam_inc_weekly/inflation', y='suburb_name', data=top_suburbs_income, palette='viridis')

# Add labels and title
plt.xlabel('Total Median Family Income (Inflation Adjusted)')
plt.ylabel('Suburbs')
plt.title('Top 20 Suburbs Based on Median Family Income (Inflation Adjusted)')

# Show the plot
plt.tight_layout()
plt.savefig('../../plots/top20SuburbsMedianFamilyIncome.png', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1185/2739280130.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Median_tot_fam_inc_weekly/inflation', y='suburb_name', data=top_suburbs_income, palette='viridis')

# %%
# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Median_tot_fam_inc_weekly/inflation', 
            y='suburb_name', 
            data=top_suburbs_income, 
            hue='suburb_name', 
            palette='cividis', 
            dodge=False)  # Add dodge=False to avoid multiple bars per hue

# Disable the legend since it's not necessary in this case
plt.legend([],[], frameon=False)

# Add labels and title
plt.xlabel('Total Median Family Income (Inflation Adjusted)')
plt.ylabel('Suburbs')
plt.title('Top 20 Suburbs Based on Median Family Income (Inflation Adjusted) - 2023')

# Show the plot
plt.tight_layout()
plt.savefig('../../plots/top20SuburbsMedianFamilyIncome2023.png', bbox_inches='tight')
plt.show()

# %%
# Filter the DataFrame for the year 2023
df_2023 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Create a scatter plot using Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Average_household_size', 
                y='average_weekly_rent/inflation/household_size', 
                data=df_2023, 
                palette='viridis')

# Add labels and title
plt.xlabel('Average Household Size')
plt.ylabel('Adjusted Average Weekly Rent (Inflation / Household Size)')
plt.title('2023: Average Household Size vs. Adjusted Average Weekly Rent')

# Save the plot
plt.tight_layout()
plt.savefig('../../plots/householdSizeVsAvgWeeklyRent_2023.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1185/4192497103.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Average_household_size',

# %%
# Filter the DataFrame for the year 2023
df_2023 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Create a scatter plot using Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Median_age_persons', 
                y='average_weekly_rent/inflation/household_size', 
                data=df_2023, 
                palette='viridis')

# Add labels and title
plt.xlabel('Median Age of Persons')
plt.ylabel('Adjusted Average Weekly Rent (Inflation / Household Size)')
plt.title('2023: Median Age of Persons vs. Adjusted Average Weekly Rent')

# Save the plot
plt.tight_layout()
plt.savefig('../../plots/medianAgeVsAvgWeeklyRent_2023.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1185/4286192848.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Median_age_persons',

# %%
# Filter the DataFrame for the year 2023
df_2023 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Group by 'suburb_name' and get the max 'Median_age_persons' for each suburb
top_suburbs_age = df_2023.groupby('suburb_name')['Median_age_persons'].max().reset_index()

# Sort the suburbs based on 'Median_age_persons' and get the top 20
top_suburbs_age = top_suburbs_age.sort_values(by='Median_age_persons', ascending=False).head(20)

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Median_age_persons', y='suburb_name', data=top_suburbs_age, palette='magma')

# Add labels and title
plt.xlabel('Median Age of Persons')
plt.ylabel('Suburbs')
plt.title('Top 20 Suburbs by Median Age of Persons - 2023')

# Show the plot
plt.tight_layout()
plt.savefig('../../plots/top20SuburbsMedianAge2023.png', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1185/1348348689.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Median_age_persons', y='suburb_name', data=top_suburbs_age, palette='magma')

# %%
# Filter the DataFrame for the year 2023
df_2023 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Create a scatter plot of 'Tot_P_P' vs 'average_weekly_rent/inflation/household_size' for 2023
plt.figure(figsize=(10, 10))
sns.scatterplot(x='Tot_P_P', y='average_weekly_rent/inflation/household_size', data=df_2023)

# Add labels and title
plt.xlabel('Total Population (Tot_P_P)')
plt.ylabel('Adjusted Average Weekly Rent')
plt.title('2023: Total Population vs. Adjusted Average Weekly Rent')

# Save the plot
plt.savefig('../../plots/TotalPopulationVSAvgWeeklyRent_2023.png', bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Filter the DataFrame for the year 2023 and remove rows where airbnb_count is 0
df_2023_filtered = dfFilteredV2[(dfFilteredV2['year'] == 2023) & (dfFilteredV2['airbnb_count'] > 0)]

# Create a scatter plot of 'airbnb_count' vs 'average_weekly_rent/inflation/household_size' for 2023
plt.figure(figsize=(10, 10))
sns.scatterplot(x='airbnb_count', y='average_weekly_rent/inflation/household_size', data=df_2023_filtered)

# Add labels and title
plt.xlabel('Airbnb Count')
plt.ylabel('Adjusted Average Weekly Rent')
plt.title('2023: Airbnb Count vs. Adjusted Average Weekly Rent (Excluding Airbnb Count = 0)')

# Save the plot
plt.savefig('../../plots/AirbnbCountVSAvgWeeklyRent_2023_filtered.png', bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Filter the DataFrame for the year 2023
df_2023 = dfFilteredV2[dfFilteredV2['year'] == 2023]

# Group by 'suburb_name' and sum the 'airbnb_count'
top_suburbs_airbnb = df_2023.groupby('suburb_name')['airbnb_count'].sum().reset_index()

# Sort the suburbs based on the 'airbnb_count' values
top_suburbs_airbnb = top_suburbs_airbnb.sort_values(by='airbnb_count', ascending=False).head(20)

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='airbnb_count', y='suburb_name', data=top_suburbs_airbnb, palette='viridis')

# Add labels and title
plt.xlabel('Airbnb Count')
plt.ylabel('Suburbs')
plt.title('Top 20 Suburbs Based on Airbnb Count - 2023')

# Show the plot
plt.tight_layout()
plt.savefig('../../plots/top20SuburbsAirbnbCount2023.png', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1185/1232858774.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='airbnb_count', y='suburb_name', data=top_suburbs_airbnb, palette='viridis')
